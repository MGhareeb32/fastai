# %% [markdown]
# # Synthesize

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_path = "../../results/checkpoint-2000"
translator = pipeline(
    "translation_ar_to_en",
    model=AutoModelForSeq2SeqLM.from_pretrained(model_path),
    tokenizer=AutoTokenizer.from_pretrained(model_path))

translator(['يقول ذلك جمال عبد الناصر'] * 3)
# Out:
# /home/msid/fastai/venv/lib/python3.10/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'translation_text': 'Rr0 Do1 Ps1 Pf2 Pf2'},
#  {'translation_text': 'Rr0 Do1 Ps1 Pf2 Pf2'},
#  {'translation_text': 'Rr0 Do1 Ps1 Pf2 Pf2'}]

# %%
corpus = []
with open('../ghani.txt', 'r', encoding='utf-8') as feat:
    for i, line in enumerate(feat):
        line = line.strip()[1:-1]
        corpus.append(line)
corpus[910:915]
# Out:
# ['أعْلَنَتِ الشَّرِكَةُ عَنْ بِضَاعَتِهَا بِوَاسِطَةِ إِعْلاَناتٍ تِجَارِيَّةٍ',
#  'أُنَاشِدُكُمْ أَنْ نَعْمَلَ كَأُمَّةٍ جُمِعَتْ كَلِمَتُهَا وَوُحِّدَتْ غَايَتُهَا',
#  'إِنَّ اللَّهَ لاَ يُغَيِّرُ مَا بِقَوْمٍ حَتَّى يُغَيِّرُوا مَا بِأَنْفُسِهِمْ',
#  'إِنَّ النّبِيَّ تَوَضَّأَ فَضَاقَ عَنْ يَدَيْهِ كُمَّا جِمَازَةٍ كَانَتْ عَلَيْه',
#  'إِنْ كَانَ لَسِناً سُمِّيَ مِهْذَاراً وإِنْ كَانَ صَمُوتاً سُمِّيَ عَيِيّاً']

# %%
corpus_txfm = {corpus[i]: v['translation_text'] for i, v in enumerate(translator(corpus))}
list(corpus_txfm.items())[910:915]
# Out:
# [('أعْلَنَتِ الشَّرِكَةُ عَنْ بِضَاعَتِهَا بِوَاسِطَةِ إِعْلاَناتٍ تِجَارِيَّةٍ',
#   "Rr0 No1 Lq3! No2 O'3 Lq2! Ni1 N'2 Ja3"),
#  ('أُنَاشِدُكُمْ أَنْ نَعْمَلَ كَأُمَّةٍ جُمِعَتْ كَلِمَتُهَا وَوُحِّدَتْ غَايَتُهَا',
#   "Rr0 Oo1 Sy2! Rx1 Lq3! No2 N'3 Rc4 No5 O'6 Ce6! Rc5 No6 O'7"),
#  ('إِنَّ اللَّهَ لاَ يُغَيِّرُ مَا بِقَوْمٍ حَتَّى يُغَيِّرُوا مَا بِأَنْفُسِهِمْ',
#   "Xw1! Nr0 Vv2! Rx1 Oo2 Lq4! No3 Lq3! Rc2 Oo3 Lq5! No4 O'5"),
#  ('إِنَّ النّبِيَّ تَوَضَّأَ فَضَاقَ عَنْ يَدَيْهِ كُمَّا جِمَازَةٍ كَانَتْ عَلَيْه',
#   'Xw1! Nr0 Rc1 Rx1 Lq3! Oo2 Rx3 Oo4 Lq5! Oi4 Nm5 Xw6! Lq6! Oo5'),
#  ('إِنْ كَانَ لَسِناً سُمِّيَ مِهْذَاراً وإِنْ كَانَ صَمُوتاً سُمِّيَ عَيِيّاً',
#   'Sy1! Xw1! Nr0 Rc1 No2 Ce2! Sy2! Xw2! No1 Rx2 Nm3')]

# %%
import csv
with open(f'final_corpus_mine.csv', 'w', encoding='utf-8') as feat:
    writer = csv.writer(feat, quoting=csv.QUOTE_NONNUMERIC)
    for sent, txfm in corpus_txfm.items():
        writer.writerow([sent, txfm])

# %% [markdown]
# # TSDAE

# %%
# !pip install -Uqq sentence_transformers

from sentence_transformers import SentenceTransformer, LoggingHandler
from sentence_transformers import models, util, datasets, evaluation, losses
from torch.utils.data import DataLoader
import random

train_sentences = list(corpus_txfm.values())
train_sentences = random.sample(train_sentences, 1000)
print('\n'.join(train_sentences[:3]))

model_name = "bert-base-uncased"
# model_name = "google-bert/bert-base-multilingual-cased"
# model_name = "distilbert/distilroberta-base"
# model_name = "CAMeL-Lab/bert-base-arabic-camelbert-ca"
# model_name = "CAMeL-Lab/bert-base-arabic-camelbert-msa-sixteenth"

word_embedding_model = models.Transformer(model_name)
embedding_len = word_embedding_model.get_word_embedding_dimension()
print(embedding_len)

pooling_model = models.Pooling(embedding_len, "cls")
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])

train_dataset = datasets.DenoisingAutoEncoderDataset(train_sentences)
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)
train_loss = losses.DenoisingAutoEncoderLoss(
    model, decoder_name_or_path=model_name, tie_encoder_decoder=True
)

model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    epochs=3,
    weight_decay=0,
    scheduler="constantlr",
    optimizer_params={"lr": 3e-5},
    show_progress_bar=True,
    # output_path=f'ar_nyuad-ud/final_{SYNTH_METHOD}',
    save_best_model=True,
)
# 1m30s
# Out:
# Rr0 Ns1
# Nr0 N'1
# Rr0 Lq2! No1 Lq3! No2
# Rr0 Ps1 Pf2 Lq2! No1 ?'2
# Rr0 Lq2! No1 Nm1
# Nr0 Ja1
# Rr0 Rx1 Lq3! Oo2 Lq3! Ni2
# Rr0 No1
# Nr0 Lq2! Po1 Lq2! Oi1
# Nr0 Ja1
# 768
# When tie_encoder_decoder=True, the decoder_name_or_path will be invalid.
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.self.value.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.output.dense.weight', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.self.key.weight', 'bert.encoder.layer.1.crossattention.self.query.bias', 'bert.encoder.layer.1.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.10.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.10.crossattention.output.dense.bias', 'bert.encoder.layer.10.crossattention.output.dense.weight', 'bert.encoder.layer.10.crossattention.self.key.bias', 'bert.encoder.layer.10.crossattention.self.key.weight', 'bert.encoder.layer.10.crossattention.self.query.bias', 'bert.encoder.layer.10.crossattention.self.query.weight', 'bert.encoder.layer.10.crossattention.self.value.bias', 'bert.encoder.layer.10.crossattention.self.value.weight', 'bert.encoder.layer.11.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.11.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.11.crossattention.output.dense.bias', 'bert.encoder.layer.11.crossattention.output.dense.weight', 'bert.encoder.layer.11.crossattention.self.key.bias', 'bert.encoder.layer.11.crossattention.self.key.weight', 'bert.encoder.layer.11.crossattention.self.query.bias', 'bert.encoder.layer.11.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.self.value.bias', 'bert.encoder.layer.11.crossattention.self.value.weight', 'bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.2.crossattention.output.dense.bias', 'bert.encoder.layer.2.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.self.key.bias', 'bert.encoder.layer.2.crossattention.self.key.weight', 'bert.encoder.layer.2.crossattention.self.query.bias', 'bert.encoder.layer.2.crossattention.self.query.weight', 'bert.encoder.layer.2.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.self.value.weight', 'bert.encoder.layer.3.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.3.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.dense.weight', 'bert.encoder.layer.3.crossattention.self.key.bias', 'bert.encoder.layer.3.crossattention.self.key.weight', 'bert.encoder.layer.3.crossattention.self.query.bias', 'bert.encoder.layer.3.crossattention.self.query.weight', 'bert.encoder.layer.3.crossattention.self.value.bias', 'bert.encoder.layer.3.crossattention.self.value.weight', 'bert.encoder.layer.4.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.4.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.4.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.output.dense.weight', 'bert.encoder.layer.4.crossattention.self.key.bias', 'bert.encoder.layer.4.crossattention.self.key.weight', 'bert.encoder.layer.4.crossattention.self.query.bias', 'bert.encoder.lay ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The following encoder weights were not tied to the decoder ['bert/pooler']
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
#     <div>
#
#       <progress value='375' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [375/375 00:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %%
embeddings = model.encode(list(corpus_txfm.values())[:10_000])
print(embeddings.shape)
print('\n'.join(list(corpus_txfm.keys())[:10]))
model.similarity(embeddings[:10,:], embeddings[:10,:])
# Out:
# (10000, 768)
# لِكُلِّ إِنْسانٍ الحَقُّ في الوُجودِ والحُرِّيَّةِ والأمْنِ، والحَقُّ في حُرِّيَّةِ الرَّأْيِ والتَّعْبيرِ بِدونِ تَمْيِيزٍ بِسَبَبِ العُنْصُرِ أَوِ اللَّوْنِ أَوِ الجِنْسِ أَوِ الثَّقافَةِ أَوِ الدِّينِ أَوِ الرَّأْيِ
# طَائِرٌ مِنْ فَصيلَةِالوَزِّيَّاتِ، مِنْ رُتْبةِ الكَفِّيَّاتِ، لَهُ مِنْقارٌ عَريضٌ مُلَوَّنٌ، قَصيرُ العُنُقِ والرِّجْلَيْنِ، طَويلُ الأجْنِحَةِ، يَخْتَلِفُ عَنِ الإِوَزِّ، وَإِنْ كانَ يُشْبِهُهُ وَهُوَ طائِرٌ مائِيٌّ لَهُ قُدْرَةٌ على الطَّيَران
# يَبْلُغُ عَدَدُ حُروفِ هِجاءِ اللُّغَةِ العَرَبِيَّةِ ثَمانِيَةً وَعِشْرينَ حَرْفاً هي: ا ب ت ث ج ح خ د ذ ر ز س ش ص ض ط ظ ع غ ف ق ك ل م ن هـ و ي. وَهُوَ ما يُسَمَّى بِحُروفِ الْمَبانِ
# اِنْقَشَعَ السّحابُ» لا مَحَلَّ لها مِنَ الإِعْرابِ لأَنَّها جُمْلَةٌ اِبْتِدائِيَّةٌ، والجُمَلُ التي لها مَحَلٌّ مِنَ الإِعْرابِ، هي التي تَحَلُّ مَحَلَّ مُفْرَدٍ، أي ما لَيْس جُمْلَةً ولا شِبْهَ جُمْلَة
# جَمَاعَةٌ مِنَ النَّاسِ تَجْمَعُهُمْ رَوَابِطُ تَارِيخِيَّةٌ مُشْتَرَكَةٌ، قَدْ يَكُونُ فِيهَا مَا هُوَ لُغَوِيٌّ أوْ دِينِيٌّ أوِ اقْتِصَادِيٌّ وَلَهُمْ أهْدَافٌ مُشْتَرَكَةٌ فِي العَقِيدَةِ أَوِ السِّيَاسَةِ أَوِ الاقْتِصَاد
# لِكُلِّ إنْسَانٍ حَقُّ التَّمَتُّعِ بِكَافَّةِ الحُقُوقِ وَالحُرِّيَّاتِ دُونَ أيِّ تَمْيِيزٍ، كَالتَّمْيِيزِ بَيْنَ العُنْصُرِ أَوِ اللوْنِ أو الجِنْسِ أَوِ الدِّينِ أوِ الرَّأيِ السِّيَاسِيِّ أَوْ أَيِّ رَأيٍ آخَرَ
# آلةٌ هَوَائِيَّةٌ نُحَاسِيَّةٌ أوْ خَشَبِيَّةٌ عَلَى شَكْلِ أُسْطُوَانَةٍ فِي ثَلاَثَةِ أرْبَاعِهِ الأولَى، ثُمَّ يَتَحَوَّلُ إلَى شَكْلٍ مَخْرُوطٍ فِي أسْفَلِهِ، كَانَ العَرَبُ يَسْتَخْدِمُونَهُ أثْنَاءَ الحُرُوب
# اِتَّجَها مَعاً إِلى قَلْبِ الضَّريحِ، وَبَعْد لَمْسِ الغِطاءِ الأَخْضَرِ وَتَقْبيلِ الجَوانِبِ الأرْبَعَةِ جَلَسا يَنْظُرانِ وَيَتَأَمَّلانِ المُقْرِئِينَ وَهُمْ يُرَدِّدونَ آياتِ القُرْآنِ الكَريمِ
# حَيَوَانٌ مِنْ فَصِيلَةِ الكَلْبِيَّاتِ مِنْ رُتْبَةِ الضَّوَارِي، لَهُ خَطْمٌ قَصِيرٌ وَذَنَبٌ طَوِيلٌ، يَتَسَاقَطُ شَعْرُهُ مَرَّةً فِي كُلِّ سَنَةٍ، يُعْرَفُ فِي الحِكَايَاتِ وَالقِصَصِ بِخِدَاعِهِ وتَحَايُلِه
# مَرَضٌ عَصَبِيٌّ». وَمِنْهَا مَا هُوَ اجْتِمَاعِيٌّ، أَيْ مَا يُخْرِجُ الكَائِنَ الْحَيَّ عَنْ حَدِّ الاعْتِدَالِ مِنْ نِفَاقٍ أَوْ تَقْصِيرٍ فِي الأَمْرِ . فِي قُلُوبِهِمْ مَرَضٌ فَزَادَهُمُ اللَّهُ مَرَضا
# tensor([[1.0000, 0.9422, 0.9248, 0.9445, 0.9305, 0.9709, 0.9314, 0.9592, 0.9727,
#          0.9328],
#         [0.9422, 1.0000, 0.9316, 0.9654, 0.9668, 0.9529, 0.9735, 0.9668, 0.9835,
#          0.9805],
#         [0.9248, 0.9316, 1.0000, 0.9453, 0.9062, 0.9276, 0.8865, 0.9322, 0.9332,
#          0.9078],
#         [0.9445, 0.9654, 0.9453, 1.0000, 0.9601, 0.9428, 0.9244, 0.9472, 0.9611,
#          0.9571],
#         [0.9305, 0.9668, 0.9062, 0.9601, 1.0000, 0.9481, 0.9578, 0.9613, 0.9589,
#          0.9616],
#         [0.9709, 0.9529, 0.9276, 0.9428, 0.9481, 1.0000, 0.9457, 0.9690, 0.9774,
#          0.9321],
#         [0.9314, 0.9735, 0.8865, 0.9244, 0.9578, 0.9457, 1.0000, 0.9638, 0.9731,
#          0.9708],
#         [0.9592, 0.9668, 0.9322, 0.9472, 0.9613, 0.9690, 0.9638, 1.0000, 0.9760,
#          0.9535],
#         [0.9727, 0.9835, 0.9332, 0.9611, 0.9589, 0.9774, 0.9731, 0.9760, 1.0000,
#          0.9678],
#         [0.9328, 0.9805, 0.9078, 0.9571, 0.9616, 0.9321, 0.9708, 0.9535, 0.9678,
#          1.0000]])

# %%
from sklearn.cluster import AffinityPropagation
affinity = AffinityPropagation(random_state=5).fit(embeddings)
# Out:
# /home/msid/fastai/venv/lib/python3.10/site-packages/sklearn/cluster/_affinity_propagation.py:142: ConvergenceWarning: Affinity propagation did not converge, this model may return degenerate cluster centers and labels.
#   warnings.warn(

# %%
from sklearn.cluster import Birch
birch = Birch(n_clusters=None).fit(embeddings)

# %%
from sklearn.cluster import HDBSCAN
hdb = HDBSCAN(min_cluster_size=3, max_cluster_size=50, n_jobs=8).fit(embeddings)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=int(len(embeddings)**0.5) * 8).fit(embeddings)

# %%
from sklearn.cluster import MeanShift
meanshift = MeanShift(bandwidth=2).fit(embeddings)

# %%
from sklearn.cluster import OPTICS
optics = OPTICS(min_samples=3).fit(embeddings)
# Out:
# /home/msid/fastai/venv/lib/python3.10/site-packages/sklearn/cluster/_optics.py:1083: RuntimeWarning: divide by zero encountered in divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
from collections import defaultdict

def save_clustering(algorithm, labels):
    clusters = defaultdict(lambda: [])
    for sent, label in zip(corpus_txfm.keys(), labels):
        clusters[label].append(sent)
    
    if -1 not in clusters:
        clusters[-1] = []
    for ss in clusters.values():
        if len(ss) == 1:
            clusters[-1].extend(ss)

    clusters = {k: v for k, v in clusters.items() if len(v) > 1 or k == -1}
    clusters = {k: v for _, v, k in sorted([(len(v), sorted(v), k) for k, v in clusters.items()])}
    n_unclustered = len(clusters[-1])
    
    path = f'final_cluster_mine_{algorithm}.txt'
    print(path)
    with open(path, 'w') as file:
        file.write(f"CLUSTER_COUNT = {len(clusters)}\n")
        file.write(f"UNCLUSTERED = {n_unclustered:,} / {sum(map(len, clusters.values())):,}\n")
        for label, sents in clusters.items():
            file.write(f"\nCLUSTER {label} ({len(sents):,} sentences)\n")
            for sent in sents:
                if label == -1:
                    file.write(f" xx {sent}\n")
                else:
                    file.write(f"    {sent}\n")
    return clusters


save_clustering("affinity", affinity.labels_)
save_clustering("birch", birch.predict(embeddings))
save_clustering("hdbscan", hdb.labels_)
save_clustering("kmeans", kmeans.labels_)
save_clustering("meanshift", meanshift.labels_)
save_clustering("optics", optics.labels_)
# Out:
# final_cluster_mine_affinity.txt
# final_cluster_mine_birch.txt
# final_cluster_mine_hdbscan.txt
# final_cluster_mine_kmeans.txt
# final_cluster_mine_meanshift.txt
# final_cluster_mine_optics.txt
# {136: ['آثارُ الحُزْنِ بادِيَةٌ على وُجوهِهِمْ',
#   'حَيَاتُهُ مُكَرَّسَةٌ لأَعْمَالِ الخَيْر',
#   'دَلائِلُ الاسْتِغْرابِ بادِيَةٌ على وُجوهِهِمْ'],
#  577: ['أبِيَ اللَّحْمَ البَائِتَ أَوْ مِنْهُ',
#   'بَوَّأهُ الْمَكَانَةَ اللاَّئِقَةَ بِهِ',
#   'عَقِيدَتُهُ عَقِيدَةٌ رَاسِخَةٌ لاَ يَحِيدُ عَنْهَا'],
#  679: ['أبْدَعَتِ الطَّبِيعَةُ مَنَاظِرَ خَلابَةً سُبْحَانَ خَالِقِهَا',
#   'تَتَكَوَّنُ مَوْجَاتُ عَجَاجٍ تَقْذِفُهَا الرِّيحُ',
#   'تَوَاصَفَ السَّائِحُونَ آثَارَ الْمُدُنِ الَّتِي زَارُوها'],
#  508: ['أتْلَفَتِ النَّارُ كُلَّ أثَاثِ البَيْتِ',
#   'تَزَاحَفَ الجُنْدُ صَوْبَ سَاحَةِ الْمَعْرَكَةِ',
#   'حَضَرَ الاجْتِمَاعَ كُلُّ أَعْضَاءِ الْجَمْعِيَّةِ'],
#  304: ['أتْمَمْتُ السَّبْعِينَ الأولَى مِنْ عُمْرِي',
#   'اِنْتَهَتِ الجَوْلَةُ الأُولَى بِفَوْزِهِ',
#   'نَشَأَتْ مُمَانَعَةٌ حَقِيقِيَّةٌ بَيْنَهُمَا'],
#  574: ['أثْبَتَ الوَقَاِئعَ كَمَا شَاهَدَهَا',
#   'أعْتَقِدُ أنِّي أحْسَنْتُ الاخْتِيَارَ',
#   'اِعْتَرَكَتِ الجَماعَةُ فيما بَيْنَها'],
#  180: ['أجْرَى التَّاجِرُ حَسْماً لِمُشْترَيَاتِ زَبُونِهِ',
#   'بَذَلَ مَساعِيَ حَميدَةً لإصْلاحِ ذاتِ بَيْنِهِما',
#   'تَفَرَّغَ مُدَّةَ شَهْرٍ لإِنْجَازِ عَمَلِهِ'],
#  234: ['أحَالَتْهُ الحُكُومَةُ عَلَى الْمَعَاشِ',
#   'اِسْتَغْرَقَهُ النَّظَرُ فِي الْخَافِقِ',
#   'هَاتُوا يَا رِجَالُ إِلَى الْمَعْرَكَةِ'],
#  105: ['أدَّى الفَيَضَانُ إلَى تَهْجِيرِ السُّكَّانِ',
#   'عَمِلَ الْجُنْدِيُّ عَلَى تَنْفِيذِ الأَوَامِرِ',
#   'يَتَدارَسُ اليَهودُ كِتابَ التَّلْمودِ'],
#  112: ['أشُمُّ مِنْ بَعِيدٍ رَائِحَةَ حَرْقِ الأعْشَابِ',
#   'رَأَى في البَرِّيَّةِ كُلَّ أَنْواعِ الحَيَواناتِ',
#   'طَافَ بِالسَّائِحِ كُلَّ مَآثِرِ الْمَدِينَةِ'],
#  207: ['أصْدَرَتْ وِزَارَةُ الدَّاخِلِيَّةِ بَلاغاً حَوْلَ أَوْضَاعِ الأَمْنِ فِي البِلاَدِ',
#   'تَسْمَحُ خُصُوبَةُ الأَرْضِ بِزَرْعِ عِدَّةِ أَنْوَاعٍ مِنَ البُقُولِ',
#   'يَتَرَاقَصُ المِغْزَلُ بَيْنَ يَدَيْهَا أَمَامَ أَكْوَامٍ مِنَ الصُّوفِ'],
#  37: ['أظْهَرَ حَيَوِيَّةً فِي مُزَاوَلَتِهِ لِلْعَمَلِ',
#   'عَامَتِ الْخَوَاطِرُ فِي خَاطِرِهِ كَالفَقَاقِيعِ',
#   'قَدَّمُوا فِدَاءً لِتَخْلِيصِهِ مِنَ الأَسْرِ'],
#  381: ['أعْلَمَهُ بِالْحَقِيقَةِ بَعْدَ فَواتِ الأَوَانِ',
#   'تَخَيَّرَهُ مِنْ بَيْنِ أَعْضَاءِ الفَرِيقِ',
#   'نَهَاهُ عَنِ التَّحْرِيشِ بَيْنَ النَّاسِ'],
#  46: ['أعْلَنَتِ الشَّرِكَةُ عَنْ إفْلاَسِها',
#   'اِسْتَعارَتْ فُسْتاناً مِنْ جارَتِها',
#   'حَاوَلَ الاسْتِخْبارَ عَنْ أَحْوَالِهِ'],
#  81: ['أعْلَى شَأنَهُ لِمَكارِمِ أخْلاقِهِ',
#   'أَلْقَوْا فِي يَدِهِ زِمَامَ أُمُورِهِمْ',
#   'اِصْطَدَمَتْ مَصالِحُهُ بِمَصالِحِ جِيرانِهِ'],
#  442: ['أغْدَقَ عَلَيْهِ مِنْ مَالِهِ الشَّيْءَ الكَثِيرَ',
#   'أَخْفَى عَلَيْكِ فِعالي يَوْمَ مُعْتَرَكِي',
#   'أَشَارَتْ إِلَيْهِ بِأُصْبُعِهَا مُنْذِرَةً مُتَوَعِّدَةً'],
#  117: ['أفْرَشَ غُرْفَةَ الاسْتِقْبَالِ بِأحْسَنِ الزَّرَابِي',
#   'تَأَسَّسَتْ مَدِينَةُ مُرَّاكُشَ فِي عَصْرِ الْمُرَابِطِينَ',
#   'تَفُوحُ رَائِحَةُ الحَمَاحِمِ فِي جَوِّ البُسْتَانِ'],
#  51: ['أفْرَغَ بُنْدُقِيَّتَهُ فِي الفَرِيسَةِ',
#   'أَخْرَجَتْ فَسَاتِينَهَا مِنَ الْخِزَانَةِ',
#   'اِمْتَازَتْ عَلاَقَتُهُمَا بِالتَّحَابِّ'],
#  460: ['أقْبَلَ عَلَى الدَّرْسِ بِنَشاطٍ وَعزِيمَةٍ',
#   'جَاءَ فِي لِبَاسٍ فِيهِ تَجَوُّدٌ وَأَنَاقَةٌ',
#   'شَارَكَ فِي الْمَوْقِعَةِ بِحَمَاسٍ وبُطُولَةٍ'],
#  328: ['أقْحَمَ صَاحِبَهُ فِي مَوْضُوعٍ غَرِيبٍ عَنْهُ',
#   'بَرَّأ نَفْسَهُ مِنَ الِاتِّهَامِ الْمُوَجَّهِ إلَيْهِ',
#   'قالَتِ الْعَدَالةُ كَلِمَتَهَا فِي الْقَضِيَّةِ الْمَعْرُوضَةِ عَلَيْهَا'],
#  34: ['أقْسَمَ بِشَرَفِهِ أن يَنْتَقِمَ لِنَفْسِهِ',
#   'لَيْسَ مِنْ حَقِّهِ أَنْ يَعْزِلَهُ عَنْ عَمَلِهِ',
#   'لَيْسَ مِنْ عادَتِهِ أَنْ يَنْصَرِفَ عَنْ واجِباتِهِ'],
#  458: ['أقْفَرَتِ الأَرْضُ مِنَ النَّبَاتِ وَالحَيَوانِ',
#   'اِسْتَبْشَرَ الْفَلاَّحُ بِالْعِهَادِ أَوِ الْعِهَادَةِ',
#   'ذَهَبَتِ الْحَرْبُ بِالأَخْضَرِ وَالْيَابِسِ'],
#  31: ['أقْلَعَ عَنِ ارْتِكَابِ الْمَعاصِي وَالآثامِ',
#   'سَاعَدَ عَلَى تَوْطِينِ اللاجِئِينَ وَالْمُهَاجِرينَ',
#   'يَشْتَغِلُ فِي مَعْمَلِ الصُّلْبِ وَالْحَدِيدِ'],
#  358: ['أكَلَ إلَى أنِ اكْتَظَّ مِنَ الطَّعَامِ',
#   'اِسْتَغْرَبْتُ كَيْفَ يُغْضِي عَلَى الإهَانَةِ',
#   'حَاوَلَ أنْ يَلْتَجِئ إلَى الحِصْنِ'],
#  93: ['ألْقَى إلَيْهِ مَقَالِيدَ الأُمُورِ',
#   'اِسْتَحْوَذَتْ عَلَيْهِ فِكْرَةُ الانْتِقَامِ',
#   'تَعُوصُ عَلَيْهِ مَعَانِي الْقَصِيدَةِ'],
#  256: ['أمْتَعَهُ اللَّهُ بِالصِّحَّةِ والعَافِيَةِ',
#   'عَرَفَهُ النَّاسُ بِالْهَاجِي لِلْأَقْرَبِينَ وَالأَبْعَدِينَ',
#   'هَدَاهُ اللَّهُ إِلَى الإِيمَانِ أَوْ لِلْإِيمَانِ'],
#  257: ['أنْهَى إلَيْهِ الخَبَرَ أوِ الكِتَابَ',
#   'اِعْتَدَى عَلَيْهِ ظُلْماً وَعُدْواناً',
#   'عَقَدَ لَهُ الرِّئَاسَةَ أَوِ القِيَادَةَ'],
#  198: ['أوَى إلَيْهِ بَعْدَمَا سُدَّتِ الأبْوابُ فِي وَجْهِهِ',
#   'ثَارَ كَمَا يَثُورُ الوَحْشُ مِنْ ضَجْعَتِهِ',
#   'سَمِعَهُ مُدَنْدِناً بِكَلِمَاتٍ لَمْ يَفْهَمْ فَحْوَاهَا'],
#  497: ['أوْدَعَ كِتَابَهُ مَعْلوماتٍ جَدِيدَةً',
#   'أَصْبَحَ بَيْنَهُمَا تَفَاعُلٌ مُسْتَمِرٌّ',
#   'اِرْتَسَمَتْ أَمَامَهُ ذِكْرَيَاتُ الْمَاضِي'],
#  208: ['أوْقَعَ بِهِ شُرُوراً لَمْ يكُنْ يَتَوَقَّعُهَا',
#   'اِسْتَفْهَمَ عَن أَشْياءَ لا يَعْرِفُها',
#   'سَاقَ إلَيْهِ ثَرْوَةً لَمْ يَكُنْ يَحْلُمُ بِهَا'],
#  539: ['أَبْرَمَ عَقْداً تِجَارِيّاً مَعَ شَرِيكِهِ',
#   'أَظْهَرَ تَخَايُلاً أَمَامَ أَصْحَابِهِ',
#   'يَتَصَنَّعُ أَفْعَالاً أَمَامَ زُمَلاَئِهِ'],
#  551: ['أَتَى بِأَفْكَارٍ وَآرَاءٍ مَنْطِقِيَّةٍ',
#   'تَعَلَّلَ بِالأَوْهَامِ وَالوُعُودِ الكَاذِبَةِ',
#   'يَتَعَلَّقُ بِالأَوْهَامِ وَالوُعُودِ الكَاذِبَةِ'],
#  589: ['أَتْلَفَ الفَيَضَانُ الزَّرْعَ وَالضَّرْعَ',
#   'تَنَاقَضَ البَائِعُ والْمُشْتَرِي البَيْعَ',
#   'يَصُوغُ الصَّائِغُ الذَّهَبَ وَالفِضَّةَ'],
#  56: ['أَجابَ عَنْ رِسالَتِهِ في الحالِ',
#   'أَطْلَقَ عَلَيْهِ الرَّصاصَ مِنْ مُسَدَّسِهِ',
#   'أَقَامُوا لَهُ صَلِيباً لِتَعْذِيبِهِ'],
#  592: ['أَجَلُّ النَّوَالِ مَا وَصَلَ قَبْلَ السُّؤَالِ',
#   'تَهَوَّرَ عِنْدَمَا تَجَاوَزَ حُدُودَ الشَّرْعِ',
#   'جَاءَ يُجَاذِبُهُ أَطْرَافَ الحَدِيثِ'],
#  270: ['أَجْرَى عَمَلِيَّةً جِراحِيَّةً لاسْتِئْصالِ الزَّائِدَةِ الدُّودِيَّةِ',
#   'اِفْتَرَضَ قَاعِدَةً جَدِيدَةً لِحَلِّ الْمُعَادَلَةِ الرِّيَاضِيَّةِ',
#   'وَضَعَ الحَجَرَ الأسَاسِيَّ لِبِنَاءِ مَدْرَسَةٍ جَدِيدَةٍ'],
#  26: ['أَحَرَّرَتْ العَيْنُ فَازْدَادَ جَمَالُها',
#   'اِنْحَدَرَتِ الشَّمْسُ وَاحْتَجَبَ نِصْفُهَا',
#   'نَتُنَتِ الْجُثَّةُ فَفَاحَتْ رَائِحَتُهَا'],
#  216: ['أَحْدَثَ الزِّلْزَالُ شَرْخاً فِي جِدَارِ العِمَارَةِ',
#   'اِنْتَكَسَتِ الرَّاياتُ حِداداً على وَفاةِ الزَّعيمِ',
#   'تَصَادَقَ الصَّدِيقَانِ مُنْذُ أَيَّامِ الطُّفُولَةِ'],
#  303: ['أَحْدَثَتِ الوِزَارَةُ أقْسَاماً جَدِيدَةً بِمَدْرَسَتِنَا',
#   'وَعَدَتِ الحُرِّيَّةُ الْمَظْلومَةُ الانْتِصافَ مِنْ ظالِميها',
#   'يُجْري العَالِمُ تَجَارِبَ عِلْمِيَّةً فِي مُخْتَبَرِهِ'],
#  52: ['أَخَذَ عَلَى عَاتِقِهِ بأنْ يُسَاعِدَهُ',
#   'عَمَدَ إلى تَقْويلِهِ ما لم يَقُلْهُ',
#   'فَضَّلَ تَحَاشِيَهُ عَلَى أَنْ يَصْطَدِمَ بِهِ'],
#  225: ['أَخَذَ عُمُولَةً مِنْ أَجْلِ صَفْقَةٍ تِجَارِيَّةٍ قَامَ بِهَا ',
#   'يُعيدُ النَّظَرَ في كُلِّ أَمْرٍ يُريدُ القِيامَ بِهِ',
#   'يُقِيمُ الدَّلِيلَ عَلَى كُلِّ عَمَلٍ يَقُومُ بِهِ'],
#  591: ['أَخَذَتِ الصَّبِيَّ رِعْدَةٌ وَتَصَبَّبَ عَرَقاً',
#   'سَكَتَ الخَطِيبُ هُنَيْهَةً ثُمَّ أَرْدَفَ قَائِلاً',
#   'كَشَفَتْ مَسْتُورًا وَأَظْهَرَتْ مَخْبُوءاً'],
#  20: ['أَخْرَجَ مُسَدَّسَهُ وَأَطْلَقَ النَّارَ عَلَيْهِ',
#   'رَبَطَ دَابَّتَهُ وَدَخَلَ إلَى السُّوقِ',
#   'قَضَى حَياتَهُ وَهُوَ يَتَمَرَّسُ بِالْمَصائِبِ'],
#  355: ['أَدَواتٌ تَعودُ إلى العَصْرِ الحَجَرِيِّ',
#   'قَائِدٌ سِيَاسِيٌّ يَتَمَتَّعُ بِشَعْبِيَّةٍ كَبِيرَةٍ',
#   'مَشْرُوعٌ يَحْتَاجُ إِلَى جُهُودٍ مُتَضَافِرَةٍ'],
#  416: ['أَدْرَكَ الرَّجُلُ أَنَّ الْمَرْأَةَ إِنْسَانٌ مِنْ نَوْعِهِ',
#   'اِلْتَجَأَ إلى الحَوْقَلَةِ بَعْدَما سُدَّتِ الأَبْوابُ في وَجْهِهِ',
#   'اِنْعَرَجَ بِسَيَّارَتِهِ يَميناً لَمَّا رَأَى بَقَرَةً تَعْبُرُ الطَّريقَ'],
#  325: ['أَرَادُوا أَنْ يَتَحَاوَرُوا لِحَسْمِ الْمُشْكِلِ',
#   'اِسْتَطَاعَ أَنْ يَتَغَلَّبَ عَلَى جَمِيعِ العَقَبَاتِ',
#   'حَاوَلَ الفَرَنْسِيُّونَ أَنْ يَسْتَوْطِنُوا بِلادَ الجَزَائِرِ'],
#  376: ['أَزَالَ جُلْفَةَ الْمَوْزِ أَوِ اللَّيْمُونِ',
#   'أَشْعَلَ مَصابيحَ العِلْمِ وَالْمَعْرِفَةِ',
#   'تَفُوحُ رَائِحَةُ الشِّوَاءِ وَالأبَازِيرِ'],
#  635: ['أَشاعَ الحاكِمُ العَدْلَ بَيْنَ النَّاسِ',
#   'اِنْطَلَقَ وَجْهُ الصَّبِيِّ بَعْدَ عُبُوسٍ',
#   'بَسَطَتِ العُلومُ آفاقاً جَديدَةً أَمامَ الإِنْسانِ'],
#  177: ['أَشَعَّتِ الشَّمْسُ على الهِضابِ وَالسُّهولِ',
#   'أَنْشَأَ مَدارِسَ في الْمُدُنِ والبَوادي',
#   'قَعَدَتِ الْمَرْأَةُ عَنِ الْحَيْضِ وَالْمَوْلِدِ'],
#  593: ['أَصْبَحَ الحَقُّ بَعْدَما سادَ الظُّلْمُ',
#   'زَعَمَ النَّاسُ أَنْ سَيَظْهَرُ الوَحْشُ لَيْلاً',
#   'يَدْعو اللَّهَ أَنْ يُنْبِتَ النَّباتَ خَيْراً هَذِهِ السَّنَةَ'],
#  209: ['أَصْبَرَهُ على ما حَلَّ بِهِ مِن مُصابٍ',
#   'سَخِطَهُ لِمَا بَدَرَ مِنْهُ مِنْ سُوءٍ',
#   'عَذَرَهُ عَلَى مَا صَدَرَ مِنْهُ مِنْ قَوْلٍ'],
#  73: ['أَصْغَى إِلى أَحادِيثِهِ باهْتِمامٍ بالِغٍ',
#   'أَعْطَى مِنْ مَالِهِ مِنْ بَابِ الفَضْلِ',
#   'تَطَوَّعَ بِمَالِهِ لِمُسَاعَدَةِ الجَمْعِيَّةِ'],
#  363: ['أَظْهَرَ شَرَهاً مَا بَعْدَهُ مِنْ شَرَهٍ',
#   'أَظْهَرَ نَذَالَةً مَا بَعْدَهَا مِنْ نَذَالَةٍ',
#   'أَظْهَرَتْ دَلالاً مَا بَعْدَهُ مِنْ دَلالٍ'],
#  361: ['أَظْهَرَتِ الجَمَاعَةُ تَصَافّاً فِي أُمُورِهَا',
#   'تَكَوَّنَتْ حَلْقَةٌ مِنَ الجُمْهُورِ حَوْلَهُ',
#   'عَرَفَتِ الفُنُونُ ازْدِهَاراً فِي عَهْدِهِ'],
#  450: ['أَعَادَ تَصْحِيحَ فَاتُورَةِ الحِسَابِ',
#   'اِخْتَبَأَتِ السَّمَاءُ تَحْتَ حِجَابِ اللَّيْلِ',
#   'اِلْتَفَتَ يَسْتَطْلِعُ مَصْدَرَ الصَّوْتِ'],
#  562: ['أَعَارَهُ كِتَاباً لِمُدَّةٍ مِنَ الزَّمَنِ',
#   'رَآهُ لَيْلاً يَتَسَكَّعُ فِي الظُّلْمَةِ',
#   'شَاهَدَهُ مِنْ بَعِيدٍ بِالعَيْنِ الْمُجَرَّدَةِ'],
#  61: ['أَعْطاهُ أَقَلَّ ما يُمْكِنُ مِنَ الوَقْتِ لِيُنْجِزَ مَوْضوعَهُ',
#   'أَنْساهُ ما كانَ يُريدُ أَخْذَهُ مِنْ أَدَواتٍ لِرِحْلَتِهِ',
#   'قُلْ مَا يَعْبَأُ بِكُمْ رَبِّي لَوْلاَ دُعَاؤُكُم'],
#  96: ['أَقَامَ رَدَحاً مِنَ الدَّهْرِ فِي دِيَارِ الغُرْبَةِ',
#   'اِنْطَلَقَتْ قَافِلَةٌ مِنَ السَّيَّارَاتِ فِي اتِّجَاهِ الصَّحْرَاءِ',
#   'يَسْرُدُ آيَاتٍ مِنَ القُرْآنِ فِي كُلِّ مسَاءٍ'],
#  726: ['أَلْبَسُوا العَرُوسَ طَوْقاً جَمِيلاً',
#   'اِجْتَازَ النَّهْرَ بِوَاسِطَةِ الْمُبَطَّنَةِ',
#   'جَلَسَتْ حَزِينَةً كَسِيرَةً مُسْتَسْلِمَةً'],
#  258: ['أَلْطَفَ لَهُ القَوْلَ أَوِ السُّؤَالَ',
#   'سَاغَ لَهُ الشَّرَابُ أو الطَّعَامُ',
#   'نَزَلَتْ بِهِمُ الكَوَارِثُ وَالْمَصَائِبُ'],
#  618: ['أَمَرَ الأَميرُ بِأَنْ تُسَوَّرَ الْمَدينَةُ',
#   'تَجْرِي الرِّياحُ بِما لا تَشْتَهِي السُّفُنُ',
#   'تَجْرِي الرِّياحُ بِما لاَ تَشْتَهِي السُّفُنُ'],
#  690: ['أَمَّا البَرَكَةُ فَهِيَ النَّماءُ والزِّيادَةُ والرَّفْعُ',
#   'فَلُّ الْحَدِيدِ أَوِ الفِضَّةِ أَوِ الذَّهَبِ أَوِ النَّارِ',
#   'لِيَكُونَ صِنَاعَةً أَوْ تَصَنُّعاً أَوْ مُصَانَعَةً'],
#  640: ['أَمْرٌ مُتَعَذِّرٌ وَبَابٌ مِنَ الكُلْفَةِ شَاقٌّ',
#   'الأمَانَةُ العَامَّةُ لِجَمْعِيَّةٍ أوْ مُؤَسَّسَةٍ دَوْلِيَّةٍ',
#   'الاتِّحَادُ العَامُّ لِلأُدَبَاءِ وَالكُتَّابِ العَرَبِ'],
#  519: ['أَمْضى فَتْرَةً مِنَ الوَقْتِ في الرَّاحَةِ',
#   'وَضَعَتْ قَليلاً مِنَ البِزْرِ في الطَّعامِ',
#   'يُخَصِّصُ مَبْلَغاً مِنَ الْمَالِ لِلْمُعْوِزِينَ'],
#  347: ['أَمْلَحَ الطَّعامَ أَكْثَرَ مِنَ اللاَّزِمِ',
#   'بَقِيَ الْمَاءُ رَاكِداً فِي البِرْكَةِ',
#   'جَرَى الْمَاءُ دَافِقاً مِنَ الصِّهْرِيجِ'],
#  569: ['أَنَا فِي انْتِظَارِ تَتِمَّةِ الْمَبْلَغِ',
#   'هُوَ مِنْ أَبْطالِ سِباقِ الحَواجِزِ',
#   'هُوَ مِنْ وَطَائِدِ حُقُوقِ الإِنْسَانِ'],
#  543: ['أَنْجَزْتُ العَمَلَ طِبْقاً لِرَغْبَتِهِ',
#   'لاَحَظَ ارْتِسَامَ ابْتِسَامَةٍ عَلَى مُحَيَّاهُ',
#   'يَهْتَمُّ بِالرِّياضِيّاتِ أُسْوَةً بِأَخِيهِ'],
#  434: ['أَنْزَفَ البِئْرَ وَتَرَكَ النَّاسَ في عَطَشٍ شَديدٍ',
#   'اِشْتَعَلَتِ النِّيرانُ وَعَلا دُخانٌ أَسْوَدُ في الفَضاءِ',
#   'لاَحَظَ وُجُودَ أَشْجَارٍ جَوْفَاءَ فِي الغَابَةِ'],
#  226: ['أَنْزَلوهُ إلى أَعْماقِ الظُّلْمَةِ وَكَبَّلوهُ بِالحَديدِ',
#   'بَلَغَ بِهِ إلَى بَابِ الْمَدْرَسَةِ وَتَرَكَهُ',
#   'تَنْزِيهُهُ عَنْ كُلِّ الشَّوَائِبِ وَعَمَّا يُدَنِّسُهُ'],
#  382: ['أَوَدُّ أَنْ يَسُودَ العَدْلُ بَيْنَ النَّاسِ',
#   'اتّصَلُوا فيما بَيْنَهُمْ بَعْدَ خِلاَفٍ',
#   'يَأْمُلُ أَنْ يَهْدِيَهُ سَواءَ السَّبيلَ'],
#  426: ['أُرِيهَا السُّهَا وَتُرِينِي القَمَرَ',
#   'خَالَفَ العَقِيدَةَ فَأكْفَرَهُ الفقِيهُ',
#   'زَوَّرَ الانْتِخَابَاتِ وَجَعَلَهَا مَهْزَلَةً'],
#  479: ['أُسْدِلَ السِّتارُ على الفَصْلِ الأوَّلِ مِنَ الْمَسْرَحِيَّةِ',
#   'تَجَهَّزَتِ القَافِلَةُ فِي لَيْلَةٍ مُقْمِرَةٍ لِلسَّفَرِ',
#   'يَشْتَغِلُ جَسَّاساً فِي الجِهَازِ السِّرِّيِّ لِلأَمْنِ'],
#  145: ['أُمٌّ رَؤُومٌ تَفِيضُ بِحَنَانِ الأُمَّهَاتِ',
#   'اِكْفِهْرَارُ الوُجُوهِ يُعَبِّرُ عَنْ حَجْمِ الْمَأسَاةِ',
#   'اِنتشَرَ الجُنْدُ في الأقالِيمِ يُطْفِئونَ نارَ الفِتْنَةِ'],
#  529: ['إلْجَاءُ الْمُتَّهَمِ إلَى الاعْتِرَافِ بِالحَقِيقَةِ',
#   'رَصيدُ الدَّوْلَةِ مِنَ الذَّهَبِ في تَقَلُّصٍ',
#   'قَوِيَ الْمُتَسَابِقُ عَلَى اللِّحَاقِ بِالرَّكْبِ'],
#  527: ['إمَاطَةُ اللِّثَامِ عَنِ الجَرِيمَةِ',
#   'اِسْتِخْرَاجُ القَيْحِ مِنَ الجُرُوحِ',
#   'بَعْدَ الاطِّلاعِ على النَّتائِجِ'],
#  655: ['إِنَّ الاعْتِرَافَ بِالجَمِيلِ فَضِيلَةٌ',
#   'كَانَ هَدَفاً لاِنْتِقَادَاتٍ جَارِحَةٍ',
#   'كَانَتِ الغَلَبَةُ لِلْفَرِيقِ الأَقْوَى'],
#  691: ['إِنَّ» تَنْصِبُ الاسْمَ وَتَرْفَعُ الْخَبَرَ، وَهِيَ تُفِيدُ التَّرَجِّي',
#   'لَمْ يَكُنْ يَعْرِفُ الحَقيقَةَ، فانْخَدَعَ',
#   'مَا أدْرِي أَأَصَبْتُ أمْ أَخْطَأْتُ». د. لَيْتَ شِعْرِ'],
#  248: ['إِنَّهَا فَتْرَةٌ مِنْ فَتَرَاتِ الْهَرِيئَةِ',
#   'لَهَا الْمُسْتَمِعُ إِلَى حَدِيثِ الْخَطِيبِ',
#   'لَهُ مَهَارَةٌ عَلَى تَدْجِينِ الحَيَوَانَاتِ'],
#  734: ['الأَحْوَالُ الاقْتِصَادِيَّةُ مُتَغَيِّرَةٌ مُتَطَوِّرَةٌ',
#   'الحَضَارَةُ الْمُعَاصِرَةُ حَضَارَةٌ إلِيكتِرُونِيَّةٌ',
#   'الْحِوَارُ الْعَرَبِيُّ الأُورُوبِّيُّ مُسْتَمِرٌّ'],
#  668: ['الأَمْرُ بِالْمَعْرُوفِ وَالنَّهْيُ عَنِ الْمُنْكَرِ',
#   'مُتَمَرِّغٌ فِي الوَحَلِ أَوْ فِي التُّرَابِ',
#   'مُكَلَّفٌ بِالأَعْمَالِ فِي سِفَارَةٍ أَوْ قُنْصُلِيَّةٍ'],
#  340: ['التَّأَدُّبُ بِآدَابِ القَوْمِ فَضِيلَةٌ',
#   'التَّأَكُّدُ مِنْ صِحَّةِ الخَبَرِ فَضِيلَةٌ ',
#   'الْمُجَاهَرَةُ بِحَقَائِقِ الأُمُورِ فَضِيلَةٌ'],
#  575: ['التَّخَرُّجُ عَلَى أَيْدِي خِيرَةِ العُلَمَاءِ',
#   'مَازَالَ فِي مَرْحَلَةِ تَهْجِيَةِ الحُرُوفِ',
#   'مُتَخَصِّصٌ فِي صِنَاعَةِ سَبْكِ الْمَعَادِنِ'],
#  380: ['التَّقاعُدُ عَنِ القِيامِ بأُمُورِهِ',
#   'اِسْتَماتَ في الدِّفاعِ عَنْ وَطَنِهِ',
#   'طِفْلَةٌ فِي الْعَاشِرَةِ مِنْ عُمْرِهَا'],
#  515: ['الحَمْدُ لِلَّهِ الَّذِي أَذْهَبَ عَنَّا الحَزَنَ',
#   'ثَائِرٌ علَى مَا حَلَّ بِهِ مِنْ غُبْنٍ',
#   'صَابِرٌ عَلَى مَا حَلَّ بِهِ مِنْ مَصَائِبَ وَكَوَارِثَ'],
#  670: ['الدُّوَلُ العَرَبِيَّةُ أَعْضَاءٌ فِي الأُمَمِ الْمُتَّحِدَةِ',
#   'الْمَوْتُ الْفَادِحُ خَيْرٌ مِنَ الزِّيِّ الْفَاضِحِ',
#   'الْيَدُ الْعُلْيَا خَيْرٌ مِنَ الْيَدِ السُّفْلَى'],
#  505: ['الدُّوَلُ العَرَبِيَّةُ مِنْ بُلْدانِ عَدَمِ الانْحِيازِ',
#   'الْمُهَاجِمُ الأَيْمَنُ فِي فَرِيقِ كُرَةِ القَدَمِ',
#   'مَدْرَسَةٌ مُجَهَّزَةٌ بِكُلِّ الأَدَوَاتِ اللاَّزِمَةِ'],
#  613: ['السَّيْفُ أَصْدَقُ أَنْباءً مِنَ الكُتُبِ',
#   'السَّيْفُ أَصْدَقُ إِنْبَاءً مِنَ الكُتُبِ',
#   'الطَّيْرُ يَرْقُصُ مَذْبُوحاً مِنَ الأَلَمِ'],
#  160: ['الطَّعامُ أَهْوَنُ مِنْ أَنْ يَحُثَّ على تَناوُلِهِ',
#   'جَرَدَ الفَارِسُ سَيْفَهُ مِنْ غِمْدِهِ',
#   'حانَ الوَقْتُ لأْنْ يَسْتَفِيقَ مِنْ كَسَلِهِ'],
#  615: ['العِلْمُ في الصِّغَرِ كالنَّقْشِ على الحَجَرِ',
#   'الْعِلْمُ فِي الصِّغَرِ كَالنَّقْشِ عَلَى الْحَجَرِ',
#   'الْمَدْرَسَةُ عَلَى مَقْرُبَةٍ مِنَ البَيْتِ'],
#  495: ['اللَّهُمَّ إِنِّي أَعُوذُ بِكَ مِنْ سُلْطَانٍ جَائِرٍ وَصَدِيقٍ غَادِرٍ',
#   'اللَّهُمَّ إِنِّي أَعُوذُ بِكَ مِنْ سُلْطَانٍ جَائِرٍ وَغَرِيمٍ مَاكِرٍ',
#   'اللَّهُمَّ إِنِّي أَعُوذُ بِكَ مِنْ سُلْطَانٍ جَائِرٍ وَنَدِيمٍ فَاجِرٍ'],
#  204: ['الَّذِينَ ذَهَبُوا فِي عُيُونِهِمْ فَرْحَةُ مَنْ رَأَى وَشَافَ',
#   'نَقَدَ الدِّيكُ ثُمَّ رَفَعَ رَأْسَهُ وَهُوَ يَحْفِرُ الأرْضَ بِمِخْلَبِهِ',
#   'وَقَفُوا يَنْظُرونَ الحاوِيَ في دَهْشَةٍ وَهُوَ يُداعِبُ حَيَّاتِهِ'],
#  641: ['الْقُبَّةُ الزَّرْقَاءُ أَوِ الْخَضْرَاءُ ',
#   'الْمَرْكَزُ التِّجَارِيُّ أَوِ الصِّنَاعِيُّ',
#   'الْهَنْدَسَةُ التَّطْبِيقِيَّةُ أَوِ الْعَمَلِيَّةُ'],
#  586: ['الْكُلُّ يُرَدِّدُ هَامِساً بِالْأَدْعِيَةِ وَالتَّسَابِيحِ',
#   'تُشِيرُ السَّاعَةُ إلَى الوَاحِدَةِ والرُّبْعِ',
#   'يَشْتَغِلُ هَذَا المِذْياعُ بِالبَطَّارِيَّاتِ والكَهْرَباءِ مَعاً'],
#  525: ['الْمُنَافِقُ يُكْثِرُ الكَلاَمَ ويُقِلُّ العَمَلَ',
#   'الْمِرَاءُ يُقَسِّي القُلُوبَ وَيُورِثُ الضَّغَائِنَ',
#   'الْهَرَمُ يَهْدِمُ الْبَدَنَ وَيُنَغِّصُ الْعَيْشَ'],
#  686: ['انْتُخِبَ عُضْواً فِي الْمَجْلِسِ البَلَدِيِّ',
#   'اِشْتَرَيْتُ حِذَاءً بِخَمْسِينَ دِرْهَماً',
#   'صَادَفْنَا شَاحِنَاتٍ فِي الطَّرِيقِ السَّيَّارِ'],
#  448: ['اِبْنَتُنَا مَرْهُونَةٌ عِنْدَ الْمُخْتَارِ، وَلاَ أَسْتَطِيعُ أَنْ أَتْرُكَهَا خَادِمَةً وَرَهِينَةً',
#   'كَانَتْ صَحيفَتُهُ بَيْضاءَ، لا أَحَدَ يُشيرُ إِلَيْهِ بِسُوءٍ أَوْ لَوْمٍ',
#   'هُوَ مِن أَفضَلِهِمْ جَمِيعاً». و. فِي كُلِّ حَرْفٍ أَوِ اسْمٍ يَبْتَدِئُ بِهَمْزَةٍ مَا عَدَا الذِي سَيُذْكَرُ فِي هَمْزَةِ الوَصْل'],
#  394: ['اِتَّجَهَ عُلَمَاءُ الآثَارِ إلَى الجَنُوبِ لِلتَّنْقِيبِ فِي مَغَاوِرَ وَكُهُوفٍ قَدِيمَةٍ',
#   'اِسْتَعْمَرَتِ الدُّوَلُ الأوروبِّيَّةُ في بِدَايَةِ هَذَا القَرْنِ عَدَداً مِنْ بُلْدانِ آسِيا وَإفْرِيقِيا',
#   'يَتَجَلَّى النَّشَاطُ الاقْتِصادِيُّ لِلْبِلاَدِ فِي مَوَادِّ التَّصْدِيرِ والاسْتِيرَادِ'],
#  23: ['اِتَّخَذَ الدَّواجِنَ لِيَنْتَفِعَ بِبَيْضِها وَفِراخِها',
#   'اِلْتَزَمَ بِالإِبَانَةِ عَنْ آرائِهِ وَأفْكَارِهِ وَأَهْدَافِهِ',
#   'يُجِيبُ بِتَوَاضُعٍ يَلِيقُ بِمَكَانَتِهِ وَعَظَمَتِهِ'],
#  167: ['اِتَّسَمَتْ مُعَامَلاَتُهُمْ بِالْمُرُوءةِ',
#   'تَتَمَيَّزُ أَحْكَامُهُ بِالْمَوْضُوعِيَّةِ',
#   'تَتَّسِمُ تَصَرُّفاتُهُ بِالاسْتِقامَةِ'],
#  687: ['اِتَّفَقُوا عَلَى الْمُلاَقَاةِ مَسَاءً',
#   'تَنَهَّدْتُ مِنَ الأعْمَاقِ ارْتِيَاحاً',
#   'تَوَاعَدَا عَلَى اللِّقَاءِ صَبَاحاً'],
#  115: ['اِجْتَاحَتِ الجُيُوشُ الاسْتِعَمَارِيَّةُ البِلاَدَ فِي بِدَايَةِ القَرْنِ',
#   'نَدَّدَتِ الْمُنَظَّمَاتُ الدَّوْلِيَّةُ لِحُقُوقِ الإِنْسَانِ بِمُعَسْكَرَاتِ الاعْتِقَالِ',
#   'وَضَعَتْ وِزَارَةُ الصِّحَّةِ مُخَطَّطاً لِتَحْدِيدِ النَّسْلِ'],
#  730: ['اِجْتَمَع الرِّجَالُ يَحْلُجُونَ القُطْنَ',
#   'اِنْتَشَرَ السُّعَاةُ يَجْمَعُونَ الجِبَايَةَ',
#   'تَحَرَّكَتِ الأَغْصَانُ فَطَارَتِ العَصَافِيرُ'],
#  678: ['اِجْتَمَعَ حَوْلِي عَشَرَاتُ الأطفَالِ',
#   'جَلَسُوا حَوْلَ طاَوِلَةِ الْمُفَاوَضَاتِ',
#   'طَافَ النَّاطُورُ حَوْلَ حُقُولِ الكَرْمِ'],
#  164: ['اِجْتَمَعَتْ حَوْلَهُ دَارَةٌ مِنَ الجُمْهُورِ',
#   'تَرَكَ أَمامهُ مَجَالاً لِلتَّخْييرِ',
#   'جَاءَ عَمَلُهُ عِبَارَةً عَنْ مَهْزَلَةٍ'],
#  482: ['اِجْتَمَعُوا فِي لَيْلَةٍ سَاهِرَةٍ عَلَى الشَّرَابِ',
#   'حَصَّلَ عَلَىنقْطَةٍ جَيِّدَةٍ فِي الاِمْتِحَان',
#   'يَنْظُرُ إلى النَّاسِ الآخَرِينَ بِاسْتِعْلاَءٍ'],
#  499: ['اِحْتَاجَ اسْتِشْفَاؤُهُ إِلَى طَبِيبٍ مُخْتَصٍّ',
#   'اِكْتَأَبَ قَلْبُهُ لِلْحَوَادِثِ الدَّامِيَةِ',
#   'بَنَوْا بُيُوتَهُمْ عَلَى سَنَنٍ وَاحِدٍ'],
#  552: ['اِحْتَرِمِ الأَبْعَدِينَ وَخَاصَّةً الأَقْرَبِينَ',
#   'بَانِي القُصُورِ والمُنْشَآتِ العُمْرَانِيَّةِ',
#   'يَكْتُبُ شِعْراً غِنَائِيّاً أَوْ حَمَاسِيّاً'],
#  95: ['اِخْتَلَطَتِ الأَصْواتُ مِن نِداءِ الباعَةِ إلَى نَفْخِ الزَّمَّاراتِ',
#   'اِسْتَخْدَمَ جِهَازَ التَّبْرِيدِ للتَّخْفِيفِ مِنْ شِدَّةِ الحَرَارَةِ',
#   'يَنْدَلِعُ لِسانُ الكَلْبِ مِنْ شِدَّةِ الحَرارَةِ'],
#  533: ['اِرْتَدَتْ عِطَافاً وَانْدَسَّتْ وَسَطَ الزِّحَامِ',
#   'هَبَّتِ العَاصِفَةُ فَتَهَشَّمَ زُجَاجُ النَّوافِذِ',
#   'وَصَفَ الدَّوَاءَ وَطَرِيقَةَ العِلاَجِ'],
#  463: ['اِرْتَدَى بِيجَامَةً وَتَهيَّأ لِلنَّوْمِ',
#   'يَطْلُبُ الْهَارِبَ وَيَهْرُبُ مِنَ الطَّالِبِ',
#   'يَقْتُلُ الصَّرِيعَ وَيُجْهِزُ عَلَى الْجَرِيحِ'],
#  428: ['اِرْتَسَمَتْ عَلَى مُحَيَّاهُ ابْتِسَامَةٌ',
#   'اِسْتَفَادَ مِنْ مُلاَحظَاتِهِ السَّدِيدَةِ',
#   'شَعَرَ بِنَدَامَةٍ مَا بَعْدَهَا نَدَامَةٌ'],
#  578: ['اِرْتَكَبَ جُنْحَةً يُعَاقِبُ عَلَيْهَا القَانُونُ',
#   'اِنْتَدَبَ الْمُديرُ أُسْتاذاً لأمْرٍ يَهُمُّهُ',
#   'مُكَاشَفَةُ الْحَقَائِقِ خَيْرٌ مِنَ التَّعَامِي عَنْهَا'],
#  621: ['اِزْدَادَ عَدَدُ الأُجَرَاءِ فِي الْمَعَامِلِ',
#   'تَعَرَّضَتْ آلاَتُ الْمَصْنَعِ إِلَى تَخْرِيبٍ',
#   'رَفَعَ أَكُفَّ الضَّرَاعَةِ إِلَى السَّمَاءِ'],
#  392: ['اِزْدَهَرَتْ صِنَاعَةُ الْمُعَلَّبَاتِ فِي أُورُوبَّا',
#   'تَخَلَّصَ الحَيَوَانُ مِنْ شِبَاكِ الصَّائِدِ',
#   'تَعَرَّضَتْ نِسَاءُ القَرْيَةِ لِلسَّبْيِ'],
#  275: ['اِسْتَدَلَّ بِأَمْثِلَةٍ وَجِيهَةٍ على كَلامِهِ',
#   'اِنْحَدَرَ مِنْ أُسْرَةٍ عَريقَةٍ في نَسَبِها',
#   'تَحَدَّثَ بِصُورَةٍ خَاطِفَةٍ عَنْ رِحْلَتِهِ '],
#  386: ['اِسْتَطاعَ إِدْرَاكَ خَبَايَا الأُمُورِ',
#   'بَلَغَتْ ضَرَاوَةُ الْحَرْبِ أَقْصَاهَا',
#   'ذَهَبَتْ حَيَاتُهُ أدْرَاجَ الرِّيَاحِ'],
#  564: ['اِسْتَطَاعَتْ أنْ تَجْعَلَ تَهَيُّمَهُ بِهَا أمْراً مَلْمُوساً',
#   'عَادُوا مِنْ رِحْلَتِهِمْ مُمْتَلِئِينَ إِعْجَاباً بِمَا رَأَوْا',
#   'يَصيرُ سِرُّهُ مِرْآةً مَجْلُوَّةً يُحاذِي بِها شَطْرَ الحَقِّ'],
#  144: ['اِسْتَعْرَضَ الضَّابِطُ تَجْرِيدَةً مِنْ جُنُودِ الْمُشَاةِ',
#   'بَيْتُ الْمَالِ أمَانَةٌ فِي عُنُقِ الحَاكِمِ',
#   'شَدَّتِ القَبِيلَةُ الرِّحَالَ إلَى أمَاكِنِ الكَلإِ'],
#  330: ['اِسْتَغَلَّ جَهْلَهُ فَأخْدَعَهُ فِي أُمُورٍ كَثِيرَةٍ',
#   'سَمِعَ نَشِيجَهَا فَالْتَفَتَ إِلَيْهَا مُسْتَفْسِراً',
#   'شَلَّحَتْ وَلِيدَهَا وَوَضَعَتْهُ فِي مَاءٍ دَافِئٍ'],
#  536: ['اِسْتَغْرَقَ فِي الحَكِيِّ اللَّيْلَ كُلَّهُ',
#   'جَعَلَتْ مِنْ شَعْرِهَا ضَفِيرَةً وَاحِدَةً',
#   'سَقَطَ في مَكانِهِ يَزْفِرُ زَفيراً شَديداً'],
#  249: ['اِسْتَقْبَلَ الْمَلِكُ ضَيْفَهُ بِحُضُورِ مُدِيرِ التَّشْرِيفَاتِ',
#   'اِنْجَبَر العَظْمُ بَعْدَ شَهْرٍ مِنْ كَسْرِهِ',
#   'بَكارَةُ البِنْتِ دَليلٌ على عُذْرِيَّتِها'],
#  277: ['اِسْتَكْتَبَ عَدَدًا كَبِيراً مِنَ العامِلِينَ في إِدارَتِهِ',
#   'قَطَعَ مَسافَةً طَويلَةً على ظَهْرِ بَغْلِهِ',
#   'يَسْعَى إلى تَلْقينِ مَوادَّ جَديدَةٍ لِتَلامِيذِهِ'],
#  36: ['اِسْتَمَرَّ فِي مُغَازَلَتِهَا عَلَى الرَّغْمِ مِنْ تَمَنُّعِهَا',
#   'تَحَدَّثَ مِنْ دَوَاخِلِهِ لِيُعَبِّرَ عَنْ مَشَاعِرِهِ',
#   'نَبَثَ عَنْ أَسْرَارِهِ لِيَكْشِفَ عَنْ مَسَاوِئِهِ'],
#  224: ['اِسْتَمَعْتُمْ أَيُّها السَّادَةُ إلى حَدِيثِ الجُمُعَةِ',
#   'تُسْعِفُهُ بِنْيَتُهُ القَوِيَّةُ على اسْتِعادَةِ عافِيَتِهِ',
#   'غَرَّمَهُ الشُّرْطِيُّ لِمُخَالَفَتِهِ قَانُونَ السَّيْرِ'],
#  71: ['اِعتْمَدَ على زَميلِهِ لإنْجازِ تَمارِينِ الغَدِ',
#   'وَقَّعَ تَعَهُّداً بِعَدَمِ الْمَسِّ بِحُقُوقِ جَارِهِ',
#   'يَمْتَخِطُ فِي كُلِّ آنٍ بِسَبَبِ زُكَامِهِ'],
#  626: ['اِعْتَدَلَ الجَوُّ فَانْتَعَشَ النَّاسُ',
#   'تَهَطَّلَ الْمَطَرُ فَامْتَلأَتِ الوُدْيَانُ',
#   'ظَهَرَ الأسَدُ فاسْتَنْفَرَتِ الظِّباءُ'],
#  190: ['اِعْتَرَضَ القَرَاصِنَةُ السَّفِينَةَ فِي عُرْضِ البَحْرِ',
#   'سَفَرَتِ الرِّيحُ الغَيْمَ عَنْ وَجْهِ السَّمَاءِ',
#   'نَسَفَ الطَّائِرُ الْحَبَّ عَنْ وَجْهِ الأَرْضِ'],
#  86: ['اِعْتَرَفَ بِذَنْبِهِ أمامَ القاضي',
#   'عَادَ إِلَى بَيْتِهِ مَعَ غُبْشَةِ اللَّيْلِ',
#   'قامَ بِإِطْفاءِ النَّارِ قَبْلَ انْتِشارِها'],
#  550: ['اِعْمَلِ الخَيْرَ، والثَّوابُ عِنْدَ الثَّوَّابِ',
#   'تَعَلَّمْتُ الصَّبْرَ علَى الدَّرْسِ، وَاحْتِمَالَ العَنَاءِ فِي التَّحْصِيلِ',
#   'يَخْتَصُّ بِتَطْرِيقِ الْمَعَادِنِ، مِنْ حَدِيدٍ وَفِضَّةٍ وَذَهَبٍ'],
#  238: ['اِقْتِطَاعُ مَبلَغٍ مِنْ مَصْروفِ جَيْبِهِ',
#   'تَحَاسَبَ الشَّرِيكَانِ لِيَعْرِفا مِقْدَارَ أَرْبَاحِهِمَا',
#   'حَمَلَ الرَّبِيعَةَ لِيُظْهِرَ قُوَّةَ عَضَلاَتِهِ'],
#  336: ['اِنْتابَتْهُ رَعْشَةُ حُمَّى في اللَّيْلِ',
#   'اِنْزَوى القَوْمُ بَعْضُهُمْ على بَعْضٍ',
#   'عَافَتْهُ وِزَارَةُ الدِّفَاعِ مِنَ الْجُنْدِيَّةِ'],
#  435: ['اِنْتَهَتِ الْحَرْبُ وَبَقِيَتِ الْمَدِينَةُ يَبَاباً',
#   'تَطَلَّبَ ازْدِيَادُ الإنْتَاجِ جُهْداً وَمُثَابَرَةً',
#   'عَقَرَ السَّرْجُ أَوِ الرَّحْلُ الظَّهْرَ'],
#  561: ['اِنْتَهَكَتْ إِسْرائِيلُ الْمَسْجِدَ الأقْصَى',
#   'دَارَ بَيْنَ الْفَرِيقَيْنِ قِتَالٌ عَنِيفٌ',
#   'نَشَبَتْ بَيْنَ الفَرِيقَيْنِ مَعْرَكَةٌ دَامِيَةٌ'],
#  232: ['اِنْدَفَعَ الْجُمْهُورُ يُقَهْقِهُ فِي صَخَبٍ',
#   'ظَلَّ الْمُعَلِّمُ يُمْطِرُهُ بِوابِل مِنَ الأسْئِلَةِ',
#   'يَنْتَظِرُ الْمُنَجِّيَ لِيُخَلِّصَهُ مِنَ العَذَابِ'],
#  431: ['اِنْطَلَقَ هَائِماً عَلَى وَجْهِهِ بَيْنَ الْوِدْيَانِ وَالْجِبَالِ',
#   'صَوَّتَتْ فِي الزُّقَاقِ وَالدُّرُوبِ طَلَقَاتُ النَّارِ',
#   'يَشْعُرُ بِالغَثَيَانِ أَمَامَ الظُّلْمِ وَالقَهْرِ'],
#  711: ['اِنْطَلَقَتِ السَّفِينَةُ الفَضَائِيَّةُ',
#   'بَدَأَتِ الْمَعْرَكَةُ الانْتِخَابِيَّةُ',
#   'تَخَالَطَتِ القُوَّاتُ الْمُتَحَارِبَةُ'],
#  693: ['اِنْقَشَعَ السّحابُ، وظَهَرَتِ الشَّمْسُ',
#   'اِهْتَزَّتِ الأَرْضُ، فَحَصَلَ اِرْتِبَاكٌ فِي الْمَدِينَةِ',
#   'رَسَتِ السَّفِينَةُ، فامْتَلأَ المِينَاءُ بِالبَحَّارَةِ'],
#  80: ['اِهْتَمَّ بِتَطْوِيفِهِ أَرْجَاءَ الْمَدِينَةِ',
#   'تَجَنَّبُوا مِنْ خَضْرَائِكُمْ ذَوَاتَ الرِّيحِ',
#   'يُوقِظُ فِي نَفْسِهِ عَوَاطِفَ نَبِيلَةً'],
#  666: ['بادِيَةٌ مُنْبَسِطَةٌ فَسيحَةُ الأَرْجاءِ',
#   'شَكْلٌ هَنْدَسِيٌّ مُتسَاوِي الأَضْلاَعِ',
#   'غَنِيمَةٌ مُوَزَّعَةٌ بَيْنَ الْمُنْتَصِرِينَ'],
#  55: ['بالَغَ في إِسْرافِ ما عِنْدَهُ مِنْ مالٍ',
#   'تَعَهَّدَ بِدَفْعِ مَا عَلَيْهِ مِنْ دُيُونٍ',
#   'ذَهَبَ لِابْتِيَاعِ مَا يَحْتَاجُهُ مِنَ الْمَتْجَرِ'],
#  559: ['بَاشَرَ عَملَهُ مَعَ بِدَايَةِ الشَّهْرِ',
#   'قَرَّرَ تَصْفيَةَ الحِسَابِ مَعَ شَرِيكِهِ',
#   'يَضَعُ مَصْلَحَتَهُ فَوْقَ كُلِّ اعْتِبَارٍ'],
#  731: ['بَحَثَ الْمَسْأَلَةَ عَنْ كَثَبٍ، مِنْ كَثَبٍ',
#   'رَسَفَ فِي الأَغْلالِ، في القَيْدِ',
#   'هَذَا أقْرَبُ إلَى الوَاقِعِ، أَقْرَبُ إلى الصَّوابِ'],
#  179: ['بَرَأَ المريضُ بُرْءاً وَبَرْءاً وبروءاً',
#   'خَشَبَ الشِّعْرَ أَوِ الْكَلاَمَ أوِ الْعَمَلَ',
#   'يَمْلأُ الصَّدْرَ هَيْبَةً وإِعْجَاباً وحُبّاً'],
#  323: ['بَرِئَ المُتَّهَمُ مِنْ كُلِّ التُّهَمِ الْمُوَجَّهَةِ إِلَيْهِ',
#   'كَلَّفَهُ رَئِيسُ الدَّوْلَةِ بِأنْ يُؤَلِّفَ حُكُومَةً جَدِيدَةً',
#   'لَبِسَتْ عَارِضَةُ الأَزْيَاءِ مِعْرَضاً لِتَعْرِضَهُ عَلَى الْمُشْتَرِينَ'],
#  2: ['بَعْدَ انْتِهَاءِ السَّهْرَةِ أَوَى كُلٌّ إِلَى مَضْجَعِهِ',
#   'تَتَّسِمُ كُلُّ أَعْمَالِهِ بِطَابَعِ الجِدِّ وَالْمَسْؤُولِيَّةِ',
#   'تَكَلَّفَ أَحَدُهُما بِإعْدَادِ الحَلْوى وَالآخَرُ بِإعْدادِ الطَّعامِ'],
#  619: ['تَتَخَلَّلُ اللَّعِبَ خُشُونَةٌ مِنْ حِينٍ لآخَرَ',
#   'يَشْظَفُ عَيْشُ الرَّجُلِ مِنْ يَوْمٍ لآخَرَ',
#   'يَنْتَعِلُ البُلْغَةَ مِنْ حِينٍ لآخَرَ'],
#  478: ['تَتَشَابَكُ أُمُورُهُ يَوْماً بَعْدَ يَوْمٍ',
#   'رَكِبَ دَرَّاجَتَهُ قاصِداً مَقَرَّ عَمَلِهِ',
#   'يُراقِبُ اصْفِرارَ وَجْهِهِ يَوْماً بَعْدَ يَوْمٍ'],
#  432: ['تَتَعَاقَبُ الأَيَّامُ وَلاَ تَتَشَابَهُ',
#   'تَتَنَاوَلُهُ الأشْيَاءُ وَلاَ يَتَنَاولُهَا',
#   'يُصَادِقُنِي أَحْيَاناً ثُمَّ يُعَادِينِي'],
#  133: ['تَتَمَيَّزُ العَرَبُ بِالتَّهَالُكِ فِي حُبِّ الثَّنَاءِ',
#   'طُلِيَتْ رِجْلُهُ بِالجِصِّ عَلَى أَثَرِ كَسْرٍ',
#   'ظَهَرَ الْمَلاَّحُ بِتُبَّانِهِ عَلَى ظَهْرِ السَّفِينَةِ'],
#  283: ['تَجَنَّدَ الشَّعْبُ لِرَدِّ العُدْوَانِ الاسْتِعْمَارِيِّ',
#   'تَفَاقَمَتِ المصَائِبُ بِحُلُولِ كَوَارِثَ جَدِيدَةٍ',
#   'تَقُومُ شَرِكَةٌ بِاحْتِكَارِ الْمَوَادِّ الغِذَائِيَّةِ'],
#  32: ['تَحَرَّرَ مِنْ كُلِّ قَيْدٍ أَوِ الْتِزاَمٍ',
#   'يَهْتَمُّ بِتَرْبِيَةِ الحَيَوَانَاتِ وَالنَّبَاتَاتِ',
#   'يُشْرِفُ عَلَى تَصْدِيرِ البَضَائِعِ وَالْمَنْتُوجَاتِ'],
#  710: ['تَحَرَّكَ الأُسْطُولُ البَحْرِيُّ الحَرْبِيُّ',
#   'ذَمَتِ الرَّائِحَةُ الكَرِيهَةُ الرَّجُلَ',
#   'سَفِدَ الحَيَوانُ الذَّكَرُ الأُنْثَى'],
#  353: ['تَحَنَّى الجَالِسُ لِيَأْخُذَ قَلَماً مَرْمِيّاً عَلَى الأَرْضِ',
#   'مَضَتِ النُّفُوسُ تَسْتَشْعِرُ حَيَوِيَّةً مُشْبَعَةً بِالأَرْيَحِيَّةِ',
#   'يَنْبَغِي تَضَافُرُ الجُهُودِ لِتَحْقِيقِ تَقَدُّمٍ عِلْمِيٍّ فِي البِلاَدِ'],
#  229: ['تَحَوَّلَتْ أَحْوَالُهُ مِنْ سَيِّءٍ إِلَى أَسْوَأَ',
#   'تَرَدَّتْ أَوْضَاعُهُ مِنْ سَيِّءٍ إلَى أَسْوَأَ',
#   'مَطَّ الرَّجُلُ سِرْوَالَهُ إِلَى أَعْلَى'],
#  724: ['تَخَطَّى الأَسْلاكَ الكَهْرَبائِيَّةَ',
#   'تَنَاوَلَ مَوْضُوعاً مُتَعَدِّدَ النَّوَاحِي',
#   'زَمْخَرَتِ الحَيَواناتُ الْمُفْتَرِسَةُ'],
#  42: ['تَخَلَّلَ الصُّفُوفَ لِلْبَحْثِ عَنْ وَلَدِهِ',
#   'تُضيفُ الجِراحُ لِلْمَريضِ آلاماً على آلامِهِ',
#   'رَمَى ذَكْوَةً على النَّارِ لِيَشْتَدَّ لَهيبُها'],
#  721: ['تَخْلِيطُ الْمَوَادِّ الكِيمِيَائِيَّةِ',
#   'تَعَاوُنِيَّةُ الْمَوَادِّ الغِذَائِيَّةِ',
#   'مُعْجَمُ الْمُصْطَلَحَاتِ الكِيمِيَائِيَّةِ'],
#  316: ['تَدَاخلَتِ الأَسْلاَكُ فِيمَا بَيْنَهَا',
#   'قَرَّرُوا التَّبَاحُثَ فِيمَا بَيْنَهُمْ',
#   'قَرَّرُوا التَّبَارِي فِيمَا بَينَهُمْ'],
#  118: ['تَدُرُّ السَّمَاءُ بِالْمَطَرِ فِي لَيالِي الشِّتَاءِ',
#   'تَمَرَّدَ الجُنْدُ في الْمُعَسْكَرِ على أَوامِرِ الضُّبَّاطِ',
#   'وَضَعَ البَارُودَ فِي البَارُودَةِ لإطْلاَقِ الرَّصَاصِ'],
#  634: ['تَرَأَّسَ أَميرُ الْمُؤْمِنينَ حَفْلاً دِينِيّاً',
#   'زَعْزَعَ أَطْفالُ الحِجارَةِ الكِيانَ الصُّهْيونِيَّ',
#   'يُوَافِقُ يَوْمَ الجُمُعَةِ العِيدُ الوَطَنِيُّ'],
#  191: ['تَرَدَّدَ اسْمُهُ عَلَى كُلِّ الشِّفَاهِ',
#   'تَلْتَهِبُ نِيرَانُ الغَيْرَةِ فِي نَفْسِهِ',
#   'سَحَبَ اسْمَهُ مِنْ لاَئِحَةِ التَّرْشِيحِ'],
#  11: ['تَرَفَّلَ فِي ثِيَابِهِ أَوْ فِي مَشْيِهِ',
#   'ذَقَنَ على يَدِهِ أَوْ على عَصاهُ',
#   'ذَقَّنَ على يَدِهِ أَو على عَصاهُ'],
#  299: ['تَرَكَ أَغْرَاضَهُ الشَّخْصِيَّةَ فِي الفُنْدُقِ',
#   'تَصُبُّ مِيَاهُ الجَدْوَلِ فِي الصِّهْرِيجِ',
#   'وَضَعَ أَغْرَاضَهُ القَدِيمَةَ فِي الْمَتْلَفَةِ'],
#  141: ['تَرَكَ دَمْغَةَ أُصْبُعِهِ على الوَرَقَةِ',
#   'تَكْشِفُ طَلاَقَةُ وَجْهِهِ عَنِ الفَرَحِ',
#   'يَعيشُ كُلَّ أَيَّامِهِ على البُقولِ'],
#  199: ['تَرَكَ لَهُ وَالِدُهُ حُرِّيَّةَ الاخْتِيَارِ',
#   'طَوَّعَتْ لَهُ نَفْسُهُ الْمَسَاسَ بِحُقُوقِ النَّاسِ',
#   'كَفَّلَهُ طَوَالَ إِقَامَتِهِ فِي بَلَدِهِ'],
#  632: ['تَسَاءلَ كَيْفَ أَصْبَحَ العِلْمُ مَسْتُورًا وَالْجَهْلُ مَنْشُوراً',
#   'جَاءَ مُسْتَبْشِراً وَهُوَ يُعْلِنُ لِلنَّاسِ خَبَراً سَارّاً',
#   'لَمْ يُطِقِ الْمُتَّهَمُ صَبْراً فَنَهَضَ بَغْتَةً كَالْمُسْتَغِيثِ'],
#  50: ['تَسَلَّلَ مِنْ بَيْتِهِ إِلَى الخَارِجِ فِي هُدُوءٍ',
#   'تَمايَزَ في عَمَلِهِ عَلى الآخَرينَ',
#   'عُرِفَ بانْتِمائِهِ إلى قَبيلَةٍ كَذَا'],
#  384: ['تَسُودُ بَيْنَهُمْ عَاطِفَةُ الْقَرَابَةِ',
#   'يَتَعَاطَى وَالِدُهُ مِهْنَةَ الْمُحَامَاةِ',
#   'يَمْلِكُ الفَقِيهُ مَلَكَةَ الاِسْتِحْصَالِ'],
#  260: ['تَشْتَدُّ تَمْتَمَتُهُ مِنْ حِينٍ لآخَرَ',
#   'رَجَّحَ أحَدَ قَوْلَيْهِ عَلَى الآخَرِ',
#   'يُتْعِبُ نَفْسَهُ أَكْثَرَ مِنَ اللاَّزِمِ'],
#  680: ['تَضَايَقُوا وَتَعَاقَدُوا وَتَعَاهَدُوا وَتَنَاشَدُوا',
#   'غَرَسُوا فَأَكَلْنَا وَنَغْرِسُ فَيَأْكُلُونَ',
#   'فَسَهَوْا وَمَا غَوَوْا وَزَلُّوا وَمَا ضَلُّوا'],
#  524: ['تَضَعُ البُقْراجَ على النَّافِخِ، وَتَشْرَعُ في تَحْضيرِ الصِّينِيَّةِ',
#   'تَنْحَصِرُ صَلاةُ الْمَغْرِبِ في ثَلاثِ رَكَعاتٍ، والصُّبْحِ في رَكْعَتَيْنِ',
#   'مَرَرْتُ بِثَمانٍ مِنَ الطَّالِباتِ». وَتَثْبُتُ الياءِ في حالَةِ النَّصْب'],
#  82: ['تَطَلَّعَ إِلَى الْمُعَلِّمِ أَثْنَاءَ حَدِيثِهِ',
#   'يَشْتَغِلُ مِنْ أَجْلِ رَغيفِ أَبْنائِهِ',
#   'يُودِعُ فِي الْكُتُبِ آيَاتِ عَبْقَرِيَّتِهِ'],
#  616: ['تَعَجَّبَ الزَّائِرُ لِمَا رَأَى فِي الْمَعْرِضِ',
#   'حَاوَلَ أَنْ يَطُوفَ العَالَمَ بِالْمُنْطَادِ',
#   'حَاوَلَ أَنْ يُنْقِذَ الغَرِقَ مِنَ الغَرَقِ'],
#  156: ['تَفَاصَحَ فيِ خُطْبَتِهِ أَمَامَ الجُمْهُورِ',
#   'دَخَلَ عَلَى أهْلِهِ ليْلَةَ الزِّفَافِ',
#   'نَصَبُوا بِقَارِعَةِ الطَّرِيقِ خِيَامَهُمْ'],
#  584: ['تَكافُؤُ الْمُرَبَّعِ والْمُسْتَطيلِ مِساحَةً',
#   'حَيَواناتُ الغابَةِ وَالجَبَلِ بَرِّيَّةٌ',
#   'لَقاحُ الفِكْرِ أَو الشَّيْءِ مُطْلَقاً'],
#  189: ['تَكْتَنِفُ الشَّاطِئَ دُكْنَةٌ في لَيالِي الشِّتاءِ',
#   'يَبْلُغُ التَّمْرُ عَادَةً فِي شَهْرِ مَارِسَ',
#   'يَنْشُرُ الخُزَعْبِلاَتِ بَيْنَ النَّاسِ'],
#  385: ['تَمَيَّزَ شُغْلُهُ بِعِدَّةِ إيجَابِيَّاتٍ',
#   'حازَتْ آراؤُهُ إِعْجابَ الحاضِرينَ',
#   'يَعْتَبِرُ مِهْنَتَهُ مِهْنَةَ الْمُفْلِسِينَ'],
#  125: ['تَمَّ احْتِشَادُ جَمِيعِ القُوَّاتِ عَلَى الحُدُودِ',
#   'جَنَّسَتِ الحُكُومَةُ كُلَّ الأَجَانِبِ الرَّاغِبِينَ فِي الجِنْسِيَّةِ',
#   'حَجَبَ نُوَّابُ مَجْلِسِ الأُمَّةِ الثِّقَةَ عَنِ الحُكومَةِ'],
#  688: ['تَنَادَمُوا عَلَى الشَّرَابِ إلَى آخِرِ اللَّيْلِ',
#   'وُزِّعَتِ الجَوَائِزُ فِي آخِرِ السَّنَةِ',
#   'يَضْرِبُ فِي الفَيَافِي عَلَى غَيْرِ هُدىً'],
#  16: ['تَنَاسَقَتْ مَعَانِي النَّصِّ وَكَلِمَاتُهُ',
#   'ذَهَبَ ضَحِيَّةَ أَهْوَائِهِ وَنَزَوَاتِهِ',
#   'نَالَ جَزَاءَ اجْتِهَادِهِ وَإِخْلاَصِهِ'],
#  490: ['تَنَاوَلَ لَقْمَةً وَاحِدَةً مِنَ الطَّعَامِ',
#   'دَخَلَ الْفَوْجُ الأَوَّلُ مِنَ الْعُمَّالِ',
#   'قَرَأْتُ البَابَ الأَوَّلَ مِنَ الكِتَابِ'],
#  585: ['تُشيرُ السَّاعَةُ إلى العاشِرَةِ وَخَمْسَ عَشْرَةَ دَقيقَةً',
#   'حَمْلُ النَّاسِ عَلَى ذَلِكَ طَوْعاً وَكَرْهاً وَتَرْغِيباً وَتَرْهيباً',
#   'يضُمُّ الكِتابُ مَتْناً وَشَرْحاً وَحاشِيَةً'],
#  77: ['تُقِيمُ كُلَّ أنْوَاعِ الأوَابِدِ فِي صَحْرائِنَا',
#   'قَضَى جُلَّ حَيَاتِهِ فِي غَيَاهِبِ السُّجُونِ',
#   'يَقْضِي صُبْحَةَ يَوْمِ الأَحَدِ فِي سَرِيرِهِ'],
#  472: ['تُنَظِّفُ فُرْشَاةُ الأَسْنَانِ كُلَّ خِلاَلَةٍ',
#   'رَشَمَ إِشارَةَ الصَّليبِ أَمامَ القُدَّاسِ',
#   'يَبْلُغُ عَرْضُ الغُرْفَةِ خَمْسَةَ أَمْتَارٍ'],
#  205: ['ثُمَّ تَحَوَّلَ عَنِ الحِجَازِ عَزْمُهُ وَصَرَفَ عِنَانَهُ',
#   'وَأَنْسَى نَكْبَتِي بِجَفائِها وَتَذُوبُ أَوْجاعِي',
#   'وَجَدَ نَفْسَهُ فِي تَشَاغُلٍ عَنْ مَهَامِّهِ'],
#  305: ['جَاءتِ الأَخْبَارُ مُطَاِبقَةً لِنُبُوءتِهِ',
#   'صَارَتِ الشُّعُوبُ وَاعِيَةً بِمَصَالِحِهَا',
#   'صَارَتِ العَلاَقَاتُ مُعَكَّرَةً بَيْنَهُمَا'],
#  302: ['جَالَتْ فِي خَاطِرِهِ أَفْكَارٌ سَوْدَاءُ',
#   'عَادَتِ الفَتَاةُ إِلَى بَيْتِهَا مَزْهُوَّةً مُخْتَالَةً',
#   'نَجَمَ عَنْ عَمَلِهِ نَتَائِجُ إِيجَابِيَّةٌ'],
#  530: ['جَلَس يَصْطَلي في لَيالي الشِّتاءِ نارَ المِدْفَأَةِ',
#   'شاعِرٌ يَنْتَمي إلى عَصْرِ الاِنْبِعاثِ',
#   'نَتَائِجُ تَحْتَاجُ إِلَى إِعَادَةِ النَّظَرِ'],
#  351: ['جَوَّدَ الْمُقْرِئُ آيَاتٍ مِنَ القُرْآنِ الكَرِيمِ',
#   'خَصْخَصَتِ الدَّوْلَةُ عَدَداً مِنَ الْمُؤَسَّساتِ العُمومِيَّةِ',
#   'خَوْصَصَتِ الدَّوْلَةُ عَدَداً مِنَ الْمُؤَسَّساتِ العُمومِيَّةِ'],
#  545: ['حاوَلَ أن يُجيبَ إِلاَّ أَنَّهُ اسْتَعْجَمَ',
#   'عَلَيَّ أَنْ أَسْعَى وَلَيْسَ عَلَيَّ إِدْرَاكُ النَّجَاحِ',
#   'لا أَظُنُّ أَحَداً يَسْتَطيعُ أَنْ يُنْكِرَ ما حَدثَ'],
#  418: ['حَافَظَ عَلَى كَلاَمِهِ لَفْظاً وَمَعْنىً',
#   'يَتَفَانَوْنَ فِي عَمَلِهِمْ بِجِدٍّ وَإِخْلاِصٍ',
#   'يُغَطْرِسُ عَلَى أَقْرَانِهِ دَوْماً وَأَبَداً'],
#  104: ['حَفَرَ الجَيْشُ بُؤَراً عَلَى طُولِ الحُدُودِ',
#   'زَيَّنَ البابَ بِزَخارِفَ في مُنْتَهَى الرَّوْعَةِ',
#   'وَضَعَتْ أَحْمَرَ الشِّفَاهِ بِلَوْنِ الأُرْجُوَانِ'],
#  403: ['حَكَمَتْ عَلَيْهِ الْمَحْكَمَةُ الابْتِدَائِيَّةُ',
#   'حَكَمَتْ عَلَيْهِ الْمَحْكَمَةُ الجِنَائِيَّةُ',
#   'عَبِثَتْ بِي الْحَوَادِثُ عَبَثاً خَطِيراً'],
#  337: ['حَلَّ بِالْمَدِينَةِ قَبْلَ غُرُوبِ الشَّمْسِ',
#   'دَعَا إِلى تَطْبِيعِ العَلاَقَاتِ مَعَ العَدُوِّ',
#   'يَتَمَرَّنُ على لَعِبِ الكُرَةِ مَعَ الصِّغارِ'],
#  309: ['حَمَلَ سِكِّيناً مَصْقُولاً بَيْنَ يَدَيْهِ',
#   'قَطَعَ شَوْطاً بَعِيداً فِي مَجَالِ عَمَلِهِ',
#   'ناضَلَ الشَّعْبُ العَرَبِيُّ مِنْ أَجْلِ اسْتِقْلالِهِ'],
#  544: ['حِينَ أَذْكُرُ أَحْبَابَ قَلْبِي أَنْثُرُ أَسْمَاءَهُمْ وَاحِداً وَاحِداً',
#   'لا يَظْلِمُ اللَّهُ النَّاسَ بَلِ النَّاسُ هُمْ أَنْفُسَهُمْ يَظْلِمونَ',
#   'لاَ يَقْبَلُ اللَّهُ صَلاَةَ رَجُلٍ أتَى الصَّلاَةَ دِبَاراً'],
#  549: ['خَشَبَةٌ يُضْرَبُ بِها الثَّوْبُ عِنْدَ غَسْلِه',
#   'رِجَالٌ جَمَدَ الدَّمْعُ فِي مَآقِيهِمْ',
#   'نِعَمٌ أفَاضَها اللّهُ عَلَى عِبَادِهِ'],
#  427: ['دَحَضَ كُلَّ التُّهَمِ الْمُوَجَّهَةِ إلَيْهِ',
#   'رَدَّ كُلَّ التُّهَمِ الْمُوَجَّهَةِ إِلَيْهِ',
#   'نَفَى كُلَّ التُّهَمِ الْمُوَجَّهَةِ إِلَيْهِ'],
#  194: ['ذَكَرَ لَهُ واقِعَةً مِنْ أَيَّامِ طُفولَتِهِ',
#   'رَخَّصَ لَهُ الْمُدِيرُ بِالذَّهَابِ لِزِيَارَةِ أهْلِهِ',
#   'سَلَّمَ لَهُ رِسَالَةً مِنْ قِبَلِ أَبِيهِ'],
#  429: ['ذَهَبَ إلى حَدٍّ بَعيدٍ في لَهْوِهِ',
#   'رَأَى طَيْفاً هَاتِفاً فِي مَنَامِهِ',
#   'رَأَيْتُ الغَضَبَ بَادِياً عَلَى وَجْهِهِ'],
#  35: ['رَأى مِنْ وَاجِبِهِ أَنْ يَتَدَخَّلَ لِيَفُكَّ النِّزَاعَ',
#   'لَيْسَ بِإِمْكانِهِ أَنْ يُنْجِزَ هَذا العَمَلَ',
#   'لَيْسَ مِنْ شَأْنِهِ أَنْ يَعْتَدِيَ عَلَى أَحَدٍ'],
#  560: ['رَأَى تَحَدُّرَهُ مِنْ أَعْلَى الجَبَلِ',
#   'سَقَطَ مِنْ أَعْلَى الجَبَلِ إلَى حَضِيضِهِ',
#   'وَضَعَتْ تَحَاسِينَ فِي غُرْفَتِهَا لِتَظْهَرَ أَكْثَرَ رَوْنَقاً'],
#  212: ['رَغِبَ إِلَيْهِ أَنْ يُشارِكَ في الحَفْلِ',
#   'طَلَبَ مِنْهُ أَنْ يَسْتَشْهِدَ فِي الْمَحْكَمَةِ',
#   'يَحِقُّ لَكَ أَنْ تُشَارِكَ فِي الْمُبَارَاةِ'],
#  359: ['رَوَّى في الْمَوْضوعِ قَبْلَ أَنْ يُصْدِرَ قَراراً',
#   'وَضَعُوا رُفوداً لِلْجِدارِ قَبْلَ أَنْ يَتَهاوَى',
#   'يَنْبَغِي لِلعالِمِ أَنْ لاَ يَتَكَبَّرَ على الْمُتَعَلِّمينَ'],
#  558: ['رِوَايَةٌ مُشَوِّقَةٌ بِأَحْدَاثِهَا وَأُسْلُوبِهَا',
#   'مُعَلِّمُ نَفْسِهِ وَمُؤَدِّبُهَا أَحَقُّ بِالإجْلاَلِ',
#   'وَلَدٌ جَدِير بِالاِحْتِرَامِ لِنَبَاهَتِهِ وَسُلُوكِهِ الحَسَنِ'],
#  39: ['سَالَتْ عَيْنُهُ بِفَيْضٍ مِنَ الدُّمُوعِ',
#   'صَرَفَ هَمَّهُ إِلَى التَّخَلُّصِ مِنَ الدُّيُونِ',
#   'يَحُثُّ تَلامِذَتَهُ على الْمَزيدِ مِنَ الاجْتِهادِ'],
#  367: ['سَتَبْدَأُ الحَمْلَةُ الانْتِخابِيَّةُ في بِدايَةِ الأسْبوعِ الْمُقْبِلِ',
#   'سَيَبْدَأُ الدَّرْسُ في تَمامِ السَّاعَةِ الثَّامِنَةِ',
#   'سَيُقامُ بَيْعُ الْمَنْزِلِ بِالْمَزادِ العَلَنِيِّ'],
#  313: ['سَتَكُونُ رُحْلَتُنَا فِي الشَّهْرِ الْمُقْبِلِ إلَى شَمَالِ البِلاَدِ',
#   'لَمْ يَكُنْ رَأْيُهُ مُلائِماً لِرَأْيِ الجَمَاعَةِ',
#   'لِيَكُنْ مُقَامُهُ مُرِيحاً فِي بِلاَدِ الغُرْبَةِ'],
#  74: ['سَقَطَ مِنْ فَوْقِ الفَرَسِ عَلَى رُكْبَتِهِ',
#   'يَأْتِي بِنَوَادِرِ الكَلاَمِ فِي حَدِيثِهِ',
#   'يَحْتَاجُ إلَى أَشْياءَ شَتَّى لِسَفَرِهِ'],
#  176: ['ضَجَّتِ القَاعَةُ بِالهُتَافِ وَالتَّصْفِيقِ وَالضَّحِكِ',
#   'قَطَعَ الْمَسَافَةَ فِي ثلاثِ دَقَائِقَ وَثَانِيَةٍ وَاحِدَةٍ',
#   'يَتَسَاوى الرَّجُلُ وَالْمَرْأةُ فِي الحُقُوقِ وَالوَاجِبَاتِ'],
#  213: ['طَلَبَ إِمْهالَهُ فَتْرَةً مِنَ الوَقْتِ',
#   'عَرَفَ جِسْمُهُ ارْتِفاعاً في الحَرارَةِ',
#   'يُراجِعُ دُروسَهُ بَعيداً عَنِ الأنْظارِ'],
#  89: ['عَبَّرَتْ قَسَمَاتُ وَجْهِهِ عَنِ الامْتِعَاضِ',
#   'فَضَّلَ اسْتِيداعَ أَمْرِهِ إلى اللَّهِ',
#   'لاَحَظَ اتِّسَاعَ عَيْنَيْهِ مِنَ الدَّهْشَةِ'],
#  631: ['عَرْضُ الحُفْرَةِ لاَ يَتَجَاوَزُ شِبْراً',
#   'كَذَّابُونَ غَدَّارُونَ لاَ يَرْعَوْنَ الذِّمَامَ',
#   'مُسَامَرَةُ الأَصْدِقَاءِ لا تَنْتَهِي'],
#  310: ['عَلاَ الاحْمِرَارُ الأُفُقَ عِنْدَ غُروبِ الشَّمْسِ',
#   'هو مُسْتَعْمِلٌ ماهِرٌ لأَدَواتِ العَمَلِ',
#   'هُوَ اللَّهُ القَدِيرُ عَلَى كُلِّ شَيْءٍ'],
#  356: ['عُرِفَتْ تِلْكَ العَائِلَةُ بِأُبُوَّةٍ مِثَالِيَّةٍ',
#   'هَذَا الْمُغَنِّي يَمْتَازُ بِصَوْتٍ عَذْبٍ',
#   'يَتَرَكَّبُ هَذا الدَّوَاءُ مِنْ مَوَادَّ مُخْتَلِفَةٍ'],
#  357: ['في اسْتِطاعَتِهِ التَّوَقُّفُ عَنِ العَمَلِ',
#   'في اسْتِطاعَتِهِ القِيَامُ بِهَذَا العَمَلِ',
#   'مِنْ شِيَمِهِ الإجْنَاحُ إِلَى الْمَكَارِم'],
#  627: ['فَرَضَ الْقَاضِي النَّفَقَةَ عَلَى الزَّوْجِ',
#   'وَافَقَ الأَعْضَاءُ عَلى الْمَشْرُوعِ بِالإِجْمَاعِ',
#   'وَجَدَ العَيْشَ رَخِيّاً فِي القَرْيَةِ'],
#  692: ['فَلَمْ يَسْتَطِعْ إلاَّ أنْ يَكُونَ ثَرْثَاراً مِكْثَاراً مِهْذَاراً',
#   'لا حَوْلَ ولا قُوَّةَ إِلا بِاللَّهِ الْعَلِيِّ العَظيمِ',
#   'لاَ حَوْلَ وَلاَ قُوَّةَ إِلاَّ بِاللَّهِ العَلِيِّ العَظِيمِ'],
#  672: ['فِي مَقْعَدِ صِدْقٍ عِنْدَ مَلِيكٍ مُقْتَدِر',
#   'مِنَ الصِّفَاتِ النَّبِيلَةِ الْعِرْفَانُ بِالْجَمِيلِ',
#   'هَذَا كَلاَمٌ بَارِعٌ مِنْ صَدْرٍ وَاسِعٍ'],
#  420: ['كانَ الماءُ يَنْصَبُّ مِنْ فَوْقَ الجَبَلِ زُلالاً',
#   'كُنْتُ أَرَى في بَريقِ عَيْنَيْهِ انْدِهاشاً',
#   'لَمْ يَجِدْ فِي بِلاَدِ الهِجْرَةِ تَنَعُّماً'],
#  152: ['كانَ رَجُلاً في غايَةِ الاسْتِقامَةِ',
#   'كَانَ جَسُوراً فِي مُلاَحَقَةِ الأَعْدَاءِ',
#   'كَانَ شَارِداً فِي أثْنَاءِ الدَّرْسِ'],
#  252: ['كانَ سَلِسَ العِبارَةِ مَيَّالاً إلى الإِطْنابِ',
#   'كانَ عَدَدُ الحَاضِرِينَ اليَوْمَ أقَلَّ مِنَ الأمْسِ',
#   'كَانَ سَلِسَ العِبَارَةِ مَيَّالاً إِلَى الإِطْنَابِ'],
#  438: ['كَانَ أَكْثَرَ عِنَاداً مِنْ أَنْ يُطِيعَ',
#   'كَانَ بِالأحْرَى أنْ تُسَاهِمَ فِي الْمُسَابَقَةِ',
#   'كَانَ مِنَ الأَجْدَى أنْ تُسَافِرَ إِلَى الجَبَلِ'],
#  250: ['كَانَ تَنَشُّطُهُ الطَّرِيقَ تَعْبِيراً عَنْ نَجَاحِهِ',
#   'كَانَ تَنَفُّسُهُ تَعْبِيراً عَنِ ارْتِيَاحِهِ',
#   'كَانَ هِيَاجُهُ تَعْبِيراً عَنْ غَضَبِهِ'],
#  667: ['كَانَ صَاغِياً لَهُ بِاهْتِمَامٍ بَالِغٍ',
#   'لاَ تَجِدُهَا إلاَّ سَاجِدَةً مُتَعَبِّدَةً',
#   'ماذَا تُضْمِرُهُ لَنا الأيَّامُ القادِمَةُ'],
#  395: ['كَانَ في عِدَادِ الْمَوْتَى أَوِ الْمَفْقُودِينَ',
#   'كَانَ مِنْ وَطَائِدِ الْحَقِّ وَالعَدْلِ',
#   'كَانَتْ فِي نِهَايَةِ الْحُسْنِ وَالْبَهَاءِ'],
#  554: ['كَانَ مِثَالَ الاتّزَانِ وَالْكَمَالِ',
#   'كَانُوا مُتَمَتْرِسِينَ وَرَاءَ الصُّخُورِ وَجُذُوعِ الصَّنَوْبَرِ',
#   'كَنَّاهُ أَبا الهَوْلِ أَوبِأَبِي الْهَوْلِ'],
#  601: ['كَمَا وَرَدَ فِي الْحَدِيثِ السَّابِقِ',
#   'مَا زَالَ فِي الْمَرْحَلَةِ الأُوْلَى',
#   'مَا زَالَ مُتَابَعاً فِي قَضِيَّةٍ جِنَائِيَّةٍ'],
#  596: ['لأجْلِ أنْ تَحْتَلَّ مَكَاناً لاَئِقًا',
#   'لاَ شَيْءَ يَعْلُو عَلَى الْمَصْلَحَةِ الوَطَنِيَّةِ',
#   'لاَ شَيْءَ يُغْوِينِي عَنِ الطَّرِيقِ الْمُسْتَقِيمِ'],
#  573: ['لا تَكُنْ مِنَ الحاقِدينَ يا بُنَيَّ',
#   'مَا الْعَنَاءُ إِلاَّ فِي الاِبْتِدَاءِ',
#   'مَا هَذَا التَّطَرُّفُ فيِ الْمَوَاقِفِ'],
#  181: ['لا يملك شَيْئاً في حافِظَةِ نُقودِهِ',
#   'لا يَسْمَحُ لأحَدٍ بِتَلْويثِ سُمْعَتِهِ',
#   'لاَيَقُومُ بِعَمَلٍ إِلاَّ حَسَبَ إِرَادَتِهِ'],
#  651: ['لا يَفُلُّ الْحَدِيدَ إِلاَّ الْحَدِيدُ',
#   'لَمْ يَكُنْ يَمْلِكُ إِلاَّ بَعيراً واحِداً',
#   'هُوَ لا يَحْتَذِي إِلاَّ المِثَالَ الحَسَنَ'],
#  396: ['لاَ دَخْلَ لَهُ فِي هَذَا الْمَوْضُوعِ',
#   'لاَ غَضَاضَةَ عَلَيْكَ فِي هَذَا الفِعْلِ',
#   'لاَ مَنْدُوحَةَ لَكَ عَنْ هَذَا العَمَلِ'],
#  695: ['لاَ فِي الْعِيرِ وَلاَ فِي النَّفِيرِ',
#   'لاَ يَكُونُ ذَلِكَ إِلاَّ نَدْرَةً أَوْ فِي النَّدْرَةِ',
#   'لاَ يَكُونُ ذَلِكَ إِلاَّ نُدْرَةً أَوْ فِي النُّدْرَةِ'],
#  185: ['لاَ يَتَوَقَّفُ عَنْ أَكْلِ الْمُلَبَّسَاتِ',
#   'لاَ يَكُفُّ عَنِ ارْتِكَابِ الْمُوبِقَاتِ',
#   'لَمْ يَتَمَكَّنْ مِنْ إِرْسَالِ الرِّسَالَةِ'],
#  85: ['لاَ يَرْغَبُ فِي تَنْجِيحِهِ دُونَ اسْتِحْقَاقٍ',
#   'لَمْ يَتَحَرَّكْ قَيْدَ أُنْمُلَةٍ عَنْ رَأيْهِ',
#   'لَمْ يَعُدْ بِاسْتِطَاعَتِهِ مُوَاصَلَةُ السَّيْرِ'],
#  436: ['لاَ يَسَعُنِي أَنْ أَسْكُتَ عَنِ الظُّلْمِ',
#   'لمَْ يَسْتَطِعْ أنْ يُؤَكِّدَ الإشَاعَةَ',
#   'مَا رَأَيْتُ أَرْوَعَ مِنْ هَذَا الْمَنْظَرِ'],
#  253: ['لاَ يَعْرِفُ الوَجَلُ إِلَى قَلْبِهِ سَبِيلاً',
#   'لَمْ يَكُنْ تَسَايُرُ الغَضَبِ عَنْ وَجْهِهِ سَهْلاً',
#   'لَمْ يَكُنْ تَقْسيمُ العَمَلِ بَيْنَهُمْ عادِلاً'],
#  147: ['لاَ يَنْبَغِي الْمِسَاسُ بِحُقُوقِ الإِنْسَانِ',
#   'ما يَزالُ الطِّفْلُ في سِنِّ الرِّضاعِ',
#   'مَا يَزَالُ شَابّاً فِي مُقْتَبَلِ العُمْرِ'],
#  184: ['لَمْ أكُنْ أسْمَعُ إلاَ أصْواتَ الباكِياتِ',
#   'لَمْ نَكُنْ نَسْمَعُ إِلاَّ خَشْخَشَةَ الأَوْرَاقِ',
#   'لَمْ يَقْرَأْ إِلاَّ خَاتِمَةَ الْكِتَابِ'],
#  201: ['لَمْ يَكُنْ أَمَامَهُ إِلاَّ أَنْ يَنْصاعَ لِلأوامِرِ',
#   'لَمْ يَكُنْ أَمَامَهُ إِلاَّ اللُّجُوءُ إِلَى العَدَالَةِ',
#   'لَمْ يَكُنْ أَمَامَهُ إِلاَّ تَحَدِّي الْمَخَاطِرِ'],
#  629: ['لَهُ حَظٌّ مِنْ ثَرَاءٍ وَفَضْلٌ مِنْ نِعْمَةٍ',
#   'لَهُ مَزِيدٌ مِنَ الْمَعْرِفَةِ وَالخِبْرَةِ',
#   'لَهُ مُمْتَلَكَاتٌ فِي الْمُدُنِ والقُرَى'],
#  683: ['لَيْسَ مِنَ الصَّوَابِ التَّنَازُلُ عَنْ الحُقُوقِ',
#   'نَفَضَتْ عَنِ الْأَثَاثِ طَبَقَةً كَثِيفَةً مِنَ الْغُبَارِ',
#   'يَبْحَثُ عَنِ الاسْتِقْرارِ بَعِيدًا عَنِ الْمَشاكِلِ'],
#  623: ['ما أَخافُ إِلاَّ مِنْ سَيْلِ تَلْعَتِي',
#   'مَنْ نَظَرَ فِي العَوَاقِبِ سَلِمَ مِنَ النَّوَائِبِ',
#   'هُوَ أَصْلَحُ لِيَقومَ بِهَذَا العَمَلِ'],
#  602: ['ما كانَ لَهُ أَنْ يَنْبَطِحَ بِهَذَا الشَّكْلِ',
#   'مَا أَحْوَجَ الجَبَانَ إلَى أَنْ يَسْمَعَ أَحَادِيثَ الشُّجْعَانِ',
#   'مَا أَحْوَجَ الجَبَانَ إِلَى أَنْ يَسْمَعَ أَحَادِيثَ الشُّجْعَانِ '],
#  714: ['مَجْبُورٌ عَلَى البَقَاءِ فِي البَيْتِ',
#   'مُبَرْمِجٌ لِلْمَوَاضِيعِ فِي الْحَاسُوبِ',
#   'مُنَاوِبٌ عَلَى الحِرَاسَةِ فِي اللَّيْلِ'],
#  563: ['مَنْ تَدَخَّلَ في مَا لا يَعْنِيهِ سَمِعَ مَا لاَ يُرْضِيهِ',
#   'مَنْ تَكَلَّمَ بِما لا يَعْنيهِ سَمِعَ ما لا يُرْضيهِ',
#   'مَنْ تَكَلَّمَ بِمَا لاَ يَعْنِيهِ سَمِعَ مَا لاَ يُرْضِيهِ'],
#  699: ['مَنْ طَلَبَ الْكَثِيرَ أَضَاعَ الْيَسِيرَ',
#   'مَنْ يَزْرَعُ الرِّيحَ يَحْصُدُ العاصِفَةَ',
#   'مَنْ يَزْرَعِ الرِّيحَ يَحْصُدِ الْعَاصِفَةَ'],
#  390: ['مُتَحَفِّزٌ لِلانْقِضَاضِ عَلَى غَرِيمِهِ',
#   'مُصَمِّمٌ العَزْمَ عَلَى الْمُضِيِّ فِي عَمَلِهِ',
#   'مُفْتَقِرٌ إِلَى الذَّكَاءِ لِتُحَلَّ مَشَاكِلُهُ'],
#  349: ['نَفِدَتِ الطَّبْعَةُ الأُولَى مِنَ الْكِتَابِ',
#   'يَسْتَخْرِجُ الإنْسَانُ الْمَعَادِنَ مِنَ الأرْضِ',
#   'يُحَلَّى اللَّيْمُونُ الْمُزُّ بِالسُّكَّرِ'],
#  546: ['ولاَ تَأْتِي الغَرْبَلَةُ جَيِّدَةً إِلاَ إِذَا كَانَ غِرْباَلُ مُغَرْبِلِ الْحُبُوبِ آيةً مِنَ الدِّقَةِ',
#   'وَجَدَتِ النَّارُ فِي الْهَشِيمِ مَرْتَعاً لِتَمْتَدَّ إِلَى كُلِّ الْحُقُولِ الْمُجَاوِرَةِ',
#   'وَسَائِلُ الإِعْلاَمِ لَهَا قُوَّةٌ مُؤَثِّرَةٌ فِي الجُمْهُور'],
#  630: ['وَتَتَعَجَّبُ مِنَ الغَرِيبِ النَّادِرِ وَيُضْحِكُهَا البَدِيعُ الطَّارِئُ',
#   'وَتَعْجَبُ مِنَ الغَرِيبِ النَّادِرِ وَيُضْحِكُهَا البَدِيعُ الطَّارِئُ',
#   'وَظَلَّتْ أَيَّاماً في غَيْبوبَةٍ تامَّةٍ ثُمَّ زايَلَها الخَطَرُ'],
#  423: ['وَتَزْدَادُ بَهْجَتِي حَتَّى تَتَحَوَّلَ إِلَى فَرْحَةٍ غَامِرَةٍ',
#   'وَجَدَ نَفْسَهُ فِي مَكَانٍ مُقْلِقٍ للرَّاحَةِ',
#   'وَقَدِ اتَّشَحَتْ مَلاَمِحُهَا بِهَيْبَةٍ مُحْزِنَةٍ'],
#  372: ['وَتُحْكَى الْجُمَلُ بَعْدَ القَوْلِ فَتُعَادُ بِلَفْظِهَ',
#   'وَصَلَ بَعْضُ الأَشْخَاصِ وَلَمْ يَتَعَرَّفْ عَلَى أَسْمَائِهِمْ بَعْدُ',
#   'وَفي الصَّمْتِ تُصْبِحُ تَكْتَكاتُ السَّاعَةِ أَفاعِيَ تَتَلَوَّى فِي فِراشِكَ'],
#  206: ['وَجَدَ فِي مَوْضُوعِهِ تَضَمُّناً لأَفْكَارِ غَيْرِهِ',
#   'وَجَدَ نَفْسَهُ فِي تَحَيُّرٍ عِنْدَ مُفَتَرَقِ الطُّرُقِ',
#   'وَمَا يَعْزُبُ عَنْ رَبِّكَ مِنْ مِثْقَالِ ذَرَّةٍ'],
#  219: ['وَجَدَ فِي مُسَاكَنَتِهِمْ رَاحَةَ البَالِ',
#   'وَصَلَتْ عَلاَقَتُهُمَا إِلى حَدِّ التَّضَاغُنِ',
#   'وَقَفَ نَفْسَهُ عَلَى أَعْمَالِ الْخَيْرِ'],
#  657: ['وَصَلَ تَعْمِيمٌ إِدَارِيٌّ إِلَى الإِدَارَةِ',
#   'وَصَلَتِ الوُفُودُ الأَجْنَبِيَّةُ إِلَى الْمُؤْتَمَرِ',
#   'وَصَلَتْ بَضائِعُ جَديدَةٌ إلى السُّوقِ'],
#  15: ['يَحْتَاجُ بُلُوغُ الْمَرامِ إلَى جُهْدٍ وَصَبْرٍ',
#   'يَنْبَغِي مُعَالَجَةُ الأُمُورِ بِالأَنَاةِ وَالصَّبْرِ',
#   'يُوَزِّعُ فَائِضَ الإِنْتَاجِ عَلَى الْفُقَرَاءِ وَالْمُحْتَاجِينَ'],
#  40: ['أجَابَ عَن سُؤَالِهِ عَلَى الأثَرِ',
#   'أَقْدَمَ على إِنْقاذِهِ مِنَ الخَطَرِ',
#   'تَمَدَّدَ عَلَى أَرِيكَتِهِ لِيَقْرَأَ الجَرِيدَةَ',
#   'سَعى إلَى تَمْكِينِهِ مِنَ النَّجَاحِ'],
#  240: ['أحَلَّهُ بمَكَانٍ لاَ عَهْدَ لَهُ بِهِ',
#   'حَلَّفَتْنِي بِالحُسَيْنِ أَنْ أُصَرِّحَ لَهَا بِمَا عِنْدِي',
#   'وَضَعَتْ في السَّهْوَةِ ما لا حاجَةَ لَنا بِهِ',
#   'يُشَوِّقُنِي فِي أَمْرٍ لاَ رَغْبَةَ لِي فِيهِ'],
#  398: ['أخْجَلَهُ لِمَا بَدَرَ مِنْهُ مِنْ أَفْعَالٍ سَيِّئةٍ',
#   'اِعْتَزَّ بِما حَقَّقَهُ مِنِ انْتِصارٍ في الألْعابِ الرِّيَاضِيَّةِ',
#   'حَزَّنَهُ بِمَا حَمَلَ مِنْ أخْبَارٍ سَيِّئَةٍ',
#   'عَنَّفَهُ لِمَا بَدَرَ مِنْهُ مِنْ أَعْمَالٍ سَيِّئَةٍ'],
#  44: ['أشُمُّ رَائِحَةً تَنْبَعِثُ مِنْ إِبْطِهِ',
#   'أَرَى خُطُورَةً تَكْمُنُ فِي مَوْقِفِهِ',
#   'دَعِ الأُمورَ تَجْرِي في أَعِنَّتِها',
#   'رَأَيْتُ شَرَاراً يَتَطَايَرُ مِنْ عَيْنَيْهِ'],
#  553: ['أصْدَرَتْ وِزارَةُ الإعْلاَمِ بَيَاناً',
#   'أَصْبَحَتِ العَلاَقَاتُ بَيْنَ البَلَدَيْنِ مُتَوَتِّرَةً',
#   'أَضاءتْ حُبابَةُ الضَّوْءِ البَيْتَ',
#   'عَرَفَتْ بُيوتُ القَرْيَةِ انْدِثارًا'],
#  565: ['أضْحَتِ الحَرْبُ سَافِرَةً بَيْنَ البَلَدَيْنِ',
#   'أَنْشَدَ الشَّاعِرُ شِعْراً بَلْ نَثْراً',
#   'اِسْتَمَرَّ الجَوُّ رَدِيئاً طَوَالَ الأُسْبُوعِ',
#   'يَتَعَلَّى البِنَاءُ يَوْماً بَعْدَ يَوْمٍ'],
#  727: ['أعارَ الْمَسْأَلَةَ أَهَمِّيَّةً قُصْوَى',
#   'أَحْيَتِ الفِرْقَةُ الوَطَنِيَّةُ حَفْلَةً',
#   'تَعْرِفُ اللُّغَةُ العَرَبِيَّةُ انْتِشاراً',
#   'دَخَلَ الرَّسُولُ الْمَدِينَةَ ظَافِراً'],
#  124: ['أعَادَتْ تَنْظِيمَ الغُرْفَةِ رَأْساً عَلَى عَقِبٍ',
#   'تَرَكَتْ سِكَّةُ الفَلاَّحِ تَلَماً في الأرْضِ',
#   'تَقَبَّلَ الشَّيْخُ عَزَاءَ الرِّجَالِ فِي جَلَدٍ',
#   'وَصَّدَ النَّسَّاجُ بَعْضَ الْخَيْطِ فِي بَعْضٍ'],
#  262: ['أعْفَاهُ مِنَ الخِدْمَةِ الْمَدَنِيَّةِ أوِ العَسْكَرِيَّةِ',
#   'أفْضَلَ عَلَيْهِ فِي الحَسَبِ وَالنَّسَبِ',
#   'أَنْكَلَهُ عَنِ الشَّيْءِ أَوِ الأمْرِ',
#   'يُنَاجِي اللَّهَ فِي السِّرِّ وَالعَلاَنِيَةِ'],
#  68: ['أعْلَنَ عَنْ إقَالَةِ الوَزِيرِ مِنْ مَنْصِبِهِ',
#   'تَأَكَّدَ مِنْ مَبْلَغِ حِرْصِي عَلَى مَصْلَحَتِهِ',
#   'يَبْحَثُ عَنْ قِطَعِ الْغِيَارِ لِسَيَّارَتِهِ',
#   'يَحْرِصُ عَلَى إتْمَامِ الدَّرْسِ فِي مَوْعِدِهِ'],
#  33: ['أغَارَ القَوْمَ أوْ بِهِمْ أوْ إلَيْهِمْ',
#   'تَحَامَلَ العَمَلَ أَوْ فِيهِ أَوْ بِهِ',
#   'شَغَّبَ النَّاسَ أَوْ عَلَيْهِمْ أَوْ فِيهِمْ أَوْ بِهِمْ',
#   'عَطَّفَ وَلَدَهُ العِطَافَ أَوِ الْمِعْطَفَ وَبِهِ'],
#  29: ['أغَلَّتِ الأرْضُ بِمُخْتَلِفِ الخُضَرِ وَالفَوَاكِهِ',
#   'اِحْتَجَّ العُمَّالُ عَلى سُوءِ الْمُعَامَلَةِ وَنَقْصِ الأُجُورِ',
#   'اِنْتَهَى الْمُنَجِّدُ مِنْ تَزْيِينِ السَتَائِرِ وحَشْوِ الوَسَائِدِ والْحَشَايَا',
#   'جاءَ الجُمْهورُ مِنْ كُلِّ حَدَبٍ وَصَوْبٍ'],
#  188: ['أفْرَجَ الضَّابِطُ عَنِ السُّجَنَاءِ يَوْمَ العِيدِ',
#   'اِسْتَمَرَّتِ الحُمَّى في الارْتِفاعِ كُلَّ اللَّيْلِ',
#   'اِنْتَهَتِ الْمُبَارَاةُ بِهَدَفَيْنِ مُقَابِلَ هَدَفَيْن',
#   'رَأَى النَّاسَ فِي لَفَفٍ حَوْلَ الْمَائِدَةِ'],
#  510: ['أفْرَزَتْ لَجْنَةُ الانْتِخَابِ أَصْوَاتَ النّاخِبِينَ',
#   'اِمْتَدَّ سُقُوطُ الأَمْطَارِ طُولَ النَّهَارِ',
#   'تَعَقَّبَ رِجَالُ الدَّرَكِ سَيَّارَةَ الْمُجْرِمِ',
#   'تُصَارِعُ آرَاءُ الْمُحَافِظِينَ آرَاءَ الْمُتَمَدِّنِينَ'],
#  84: ['أفْرَغَ كُلَّ إمْكَاناتِهِ فِي العَمَلِ',
#   'أَطْلَقَ نارَ بُنْدُقِيَّتِهِ على لِصٍّ',
#   'شَغَلَ أَوْقَاتَ فَرَاغِهِ بِالرِّياضَةِ',
#   'وَضَعَ بَصْمَةَ إِبْهامِهِ على الوَرَقَةِ'],
#  471: ['أفْطَرَ الصَّائِمُ بَعْدَ أَذانِ الْمَغْرِبِ',
#   'تَدَافُعُ الجُمْهُورِ أَمَامَ بابِ الْمَلْعَبِ',
#   'تَرَنَّحَتِ السَّفِينَةُ بَعْدَ هُبُوبِ العَاصِفَةِ',
#   'خَيَّمَ السُّكُونُ بَعْدَ هُبُوبِ العَاصِفَةِ'],
#  308: ['أقَرَّ العَاشِقَانِ بِحُبِّهِما الْمُتبَادَلِ',
#   'اِسْتَمَرَّ اعْتِكافُهُ في البَيْتِ زَمَناً طَويلاً',
#   'اِعْتَزَلَ العَمَلَ بِسَبَبِ ظُروفِهِ الصِّحِّيَّةِ',
#   'تَسَابَقَ مَعَهُ لِلْفَوْزِ بِالرُّتْبَةِ الأُولَى'],
#  518: ['أقْدَمَتْ عَلَى عَمَلٍ مِنَ الخُطُورَةِ بِمكَانٍ',
#   'أَصَرَّ على السَّفَرِ بِالرغمِ من الْمَخاطِرِ',
#   'غَاصَ فِي البَحْرِ بَحْثاً عَنِ اللُّؤْلُؤِ',
#   'وَضَعَ عَلَى القَبْرِ تَرْكِيبَةً مِنَ الرُّخَامِ'],
#  732: ['أقْطَعَ الأَميرُ الجُنْدَ البلَدَ',
#   'تَحَقَّقَ السَّلاَمُ بَعْدَ حَرْبٍ مَهُولَةٍ',
#   'تَكَلَّفَ الضَّحِكَ أَمامَ الحاضِرينَ',
#   'جَرَفَتِ الأَمْطَارُ الغَزِيرَةُ الْمَاشِيَةَ'],
#  636: ['ألْقَى الكَلِمَةَ الْخِتَامِيَّةَ رَئِيسُ الْجَمْعِيَّةِ',
# ...
#   'الاِسْتِبْدَادُ يَرْتَجِفُ مِنْ صَوْلَةِ الْعِلْمِ',
#   'الباقِي مِنَ الدَّقِيقِ لاَ يَكْفِي لِيَوْمٍ واحِدٍ',
#   'البَطُّ لَهُ يَقَظَةٌ حارِسَةٌ تَدُلُّ على حِدَّةِ حَدْسِهِ',
#   'البَلاغَةُ هِيَ الجِدُّ وَهِيَ الجامِعَةُ ثَمَراتِ العَقْلِ',
#   'البَيِّنَةُ عَلَى مَنِ ادَّعَى واليَمِينُ على مَنْ أَنْكَرَ',
#   'البُعْدُ جَفَاءٌ وَمَا لاَ تَرَاهُ العُيُونُ لاَ تَرْثِي لَهُ القُلُوبُ',
#   'التَّاسِعُ مِنْ بَيْنِ الْمُتَنَافِسِينَ',
#   'التَّحَاكُمُ خَيْرٌ مِنَ الاسْتِمْرَارِ فِي التَّخَاصُمِ',
#   'التَّحَرُّجُ مِنْ إِتْيَانِ الآثَامِ فَضِيلَةٌ وَسُلُوكٌ أَخْلاَقِيٌّ',
#   'التَّدْخِينُ مُضِرٌّ بِصِحَّةِ الإِنْسَانِ',
#   'التَّزَاحُمُ الرَّهِيبُ يَنْفِي الفِكْرَ، يَنْبِذُهُ وَيَدُوسُهُ',
#   'التَّزْوِيدُ بِمَا يَكْفِي مِنَ الْمُؤَنِ',
#   'التَّسَاكُنُ فِي العِمَارَةِ نَفْسِها',
#   'التَّصَاغُرُ دَوَاءُ النَّفْسِ وَسَجِيَّةُ أَهْلِ البَصِيرَةِ فِي الدُّنْيَا والدِّينِ',
#   'التَّصَاغُرُ دَوَاءُ النَّفْسِ وَسَجِيَّةُ أَهْلِ البَصِيرَةِ فِي الدُّنْيَا وَالدِّينِ',
#   'التَّصَوُّفُ يَكُونُ بِالْمُجَاهَدَةِ وَقَطْعِ الشَّهْوَةِ',
#   'التَّصْرِيحُ غَالبًا مُتَصَدِّراً وَالتَّعْوِيضُ قَلِيلاً يَسِيراً',
#   'التَّصْلِيبُ فِي الصَّلاَةِ عِنْدَ الْمَسِيحِيِّينَ',
#   'التَّطَرُّقُ إِلىَ الْمَوْضُوعِ مُبَاشَرَةً',
#   'التَّطَهُّرُ ضَرُورِيٌّ قَبْلَ أَدَاءِ الصَّلاَةِ',
#   'التَّطَهُّرُ مِنْ كُلِّ مَا يُدَنِّسُكَ وَيُبْعِدُكَ عَنِ الأَشْرَارِ',
#   'التَّطَوُّعُ مِنْ أَجْلِ أَعْمَالٍ خَيْرِيَّةٍ',
#   'التَّطْويفُ بَيْنَ البُيُوتِ والعِمارَاتِ',
#   'التَّعَدِّي عَلَى حُرْمَةِ الغَيْرِ يُعَاقِبُ عَلَيْهِ القَانُونُ',
#   'التَّقَرُّبُ إلى اللَّهِ بِالدُّعاءِ الصَّالِحِ',
#   'التَّلْقِيحُ ضَرُورَةٌ لِكُلِّ إنْسَانٍ لِلْحَصَانَةِ مِنَ الأمْرَاضِ الْمُعْدِيَةِ',
#   'التَّنَقُّلُ حَقٌّ مِنْ حُقُوقِ الإنْسَانِ',
#   'التَّوَاضُعُ مَعْنىً يَنْتظِمُ بِهِ جِمَاعُ الخَيْرِ وَالتَّواضُعُ عَقِيبُ الكِبْرِ',
#   'التَّوَزُّعُ بَيْنَ الأَفْكَارِ أَوِ الآرَاءِ أوِ الْمَوَاقِفِ',
#   'التَّوْريَةُ فِي البَدِيعِ، الإتْيَانُ بِلَفْظٍ لَهُ مَعْنَيان، مَعْنىً قَرِيبٌ ظَاهِرٌ غَيْرُ مَقْصُودٍ، وَمَعْنىً بَعِيدٌ خَفِيٌّ هُوَ المقْصُود',
#   'التَّوْسِيلُ إلَى اللَّهِ بِالعَمَلِ الصَّالِحِ',
#   'التَّيَّارُ الكَهْرَبَائِيُّ مُنْقَطِعٌ مُنْذُ الصَّبَاحِ',
#   'الثَّبَاتُ هُوَ فِي طِبَاعِ الذِّئْبِ وَالتَّحَرُّزُ هُوَ فِي طِبَاعِ الجَامُوسِ',
#   'الثَّعابينُ والْحَيَّاتُ مِنَ الْحَيَواناتِ الزَّواحِفِ',
#   'الجَامُوسُ لاَ يَنَامُ أَصْلاً وَإِنْ أَرْخَى عَيْنَيْهِ إِرْخَاءً يَسِيراً',
#   'الجَمَلُ ذُو سِنَامٍ مُقَبَّبٍ يَكُونُ لِكَثْرَةِ الحِمْلِ وَاحْتِمَالِ الثِّقْلِ',
#   'الجَنَّةُ دَرَجَاتٌ وَالنَّارُ دَرَكَاتٌ',
#   'الجَنَّةُ لِلْمُتَّقِينَ». و. القَسَم',
#   'الجَوَابُ مَا تَرَى لاَ مَا تَسْمَعُ',
#   'الجِسْمُ إِذَا قَبِلَ صُورَةً أَوْ شَكْلاً كَالتَّثْليثِ فَلاَ يَقْبَلُ التَّرْبيعَ والتَّدْويرَ',
#   'الجِهَازُ الهَضْمِيُّ» وَ«الجِهَازُ التَّنَفُّسِيُّ',
#   'الجِهَازُ الْمُكَثِّفُ فِي الرَّادْيُو',
#   'الحَالَةُ التِي تَخْرُجُ مِنَ الحُكْمِ أَوِ القَاعِدَةِ العَامَّةِ». حَضَرَ الجَمِيعُ بِاسْتِثْنَاءِ وَاحِدٍ',
#   'الحَالَةُ الرَّاهِنَةُ لِلْمَرِيضِ لاَ تَدْعُو لِلْقَلَقِ',
#   'الحَسَدُ دَاءٌ يُنْهِكُ الْجَسَدَ وَيُفْسِدُ الوَدَّ',
#   'الحَسَدُ يَأْكُلُ الحَسَنَاتِ كَمَا تَأْكُلُ النَّارُ الحَطَبَ',
#   'الحَسُودُ لاَ يَسُودُ',
#   'الحَقِيقَةُ لاَ يَرْتَابُ فِيهَا إِنْسَانٌ',
#   'الحَقُّ يُقَالُ إِنَّهُ عَادِلٌ فِي أَحْكَامِهِ',
#   'الحَمْدُ لِلَّهِ الحَلِيمُ الأحْلَمُ',
#   'الحَمْدُ لِلَّهِ العَظِيمِ الأعْظَمِ الحَكِيمِ الأحْكَمِ',
#   'الحَمْدُ لِلَّهِ الَّذِي لا يُحْمَدُ على السَّرَّاءِ والضَّرَّاءِ سِواهُ',
#   'الحَمْدُ لِلَّهِ الْعَلِيمِ الأَعْلَمِ',
#   'الحَمْدُ لِلَّهِ رَبِّ العَالَمِينَ وَصَلَّى اللَّهُ عَلَى نَبِيِّهِ وَعَلَى آلِهِ الطَّاهِرِينَ',
#   'الحَمْدُ لِلَّهِ رَبِّ العَالَمِينَ@«، وَهِيَ اخْتِزَالٌ لَهَ',
#   'الحَوَاسُّ الخَمْسُ لاَ تُدْرِكُ إلاَّ الأَجْسَامَ',
#   'الحُبُّ الَّذِي لاَ يَتَّصِلُ بِالصَّدِيقِ مَعْدُومُ القِيمَةِ',
#   'الحُروفُ الشَّمْسِيَّةُ: كُلُّ كَلِمَةٍ مُعَرَّفَةٍ بِأَلْ تُدْغَمُ فيها اللاَّمُ',
#   'الحُزْنُ وَالغَمُّ وَالهَمُّ وَالأَسَى وَالجَزَعُ وَالخَوَرُ مِنْ شَجَرَةٍ وَاحِدَةٍ',
#   'الحِكْمَةُ ضَالَّةُ الْمُؤْمِنِ حَيْثُمَا وَجَدَ الْمُؤْمِنُ ضَالَّتَهُ فَلْيَجْمَعْهَا إِلَيْهِ',
#   'الحِمَارُ الوَحْشِيُّ حَيَوَانٌ مُخَطَّطٌ',
#   'الحِوَارُ عُنْصُرٌ مِنَ العَنَاصِرِ الفَنِّيَّةِ لِلْقِصَّةِ وَالْمَسْرَحِيَّةِ وَالرِّوَايَةِ',
#   'الخَمِيرُ اليسِيرُ يُخَمِّرُ العَجِينَ كُلَّهُ',
#   'الخَمِيرُ الَّذِي يُخَمِّرُ الْعَجِينَ كُلَّهُ',
#   'الخُلَفَاءُ الرَّاشِدُونَ هُمْ: أبُو بَكْرٍ وَعُمَرُ وَعُثْمَانُ وَعَلِيٌّ',
#   'الدَّرَجَةُ الثَّامِنَةُ«،» تُشِيرُ السَّاعَةُ إلَى الثَّامِنَةِ صَبَاحاً',
#   'الدُّخُولِ لِلْمُتْحَفِ مُتَاحُ لِكُلِّ زَائِرٍ',
#   'الدُّمُوعُ لَمْ تَعُدْ عَلَى طَبِيعَتِهَا دُمُوعاً بَلْ هِيَ عَلاَماتُ الأَلَمِ',
#   'الدُّنْيا زُخْرُفٌ يَغْلِبُ الجوارِحَ ما لَمْ تَغْلِبْهُ الأَلْبابُ',
#   'الدُّنْيَا وَالآخِرَةُ ضَرَّتَانِ مَتَى أَرْضَيْتَ إِحْدَاهُمَا أَسْخَطْتَ الأُخْرَى',
#   'الدِّمَاءُ مَتَى سَالَتْ وَخَرَجَتْ اِنْعَقَدَتْ وَتَجَمَّدَتْ',
#   'الدِّيكُ لَهُ تَبْشِيرٌ بِإِقْبَالِ الصُّبْحِ وَطُلُوعِ الشَّمْسِ',
#   'الدِّينُ الإِسْلامِيُّ«إِنَّ الدِّينَ عِنْدَ اللَّهِ الإِسْلام',
#   'الذَّكَاءُ مِلْءُ عَيْنِ هَذَا الرَّجُلِ',
#   'الذَّهَبُ يُعْرَفُ بِالنَّارِ وَأَمَانَةُ الرَّجُلِ بِالأَخْذِ وَالعَطَاءِ',
#   'الرَّأيُ السَّدِيدُ أحْمَى مِن البَطَلِ الشَّدِيدِ',
#   'الرَّيْبُ والشَّكُّ والظَّنُّ والتَّوَهُّمُ كُلُّها من علائِقِ الحِسِّ',
#   'الرُّوحُ القُدُسُ يَنْبَثِقُ مِنَ الأَبِ والابْنِ عِنْدَ الْمَسيحيِّينَ',
#   'الرِّبَا هُوَ كَسْبٌ بِدُونِ مُقَابِلٍ مَادِّيٍّ وَفِيهِ مَعْنَى الغَصْبِ',
#   'الرِّبَاطُ هِيَ عَاصِمَةُ الْمَمْلَكَةِ الْمَغْرِبِيَّةِ',
#   'الرِّجَالُ أَرْبَعَةٌ: جَوَادٌ وَبَخِيلٌ وَمُسْرِفٌ وَمُقْتَصِدٌ',
#   'الرِّوَايَةُ مَشْهَدٌ حَيٌّ مِنْ مَشَاهِدِ الْحَيَاةِ',
#   'الزَّمانُ أعَزُّ مِنْ أنْ يُبْذَلَ فِي الأكْلِ وَالشُّرْبِ وَالتَّلَذُّذِ وَالتَّمَتُّعِ',
#   'الزَّمَنُ كَفِيلٌ بِإِصْلاَحِ مَا أَفْسَدَهُ الفَاسِدُونَ',
#   'الزَّيْتُ مَادَّةٌ مُسْتَهْلَكَةٌ فِي الْمَطْبَخِ العَرَبِيِّ',
#   'السَّاكِنُ فِي ذَنَبِ البَيْتِ قَدِ ارْتَحَلَ',
#   'السَّكْتُ فِي الغِنَاءِ أَو فِي القِرَاءةِ',
#   'السَّلامُ على كُلِّ طِفْلٍ تَعَلَّمَ كَيْفَ يَصوغُ الحِجارَةَ',
#   'السَّلامُ عَلَيْكُمْ وَرَحْمَةُ اللَّهِ تَعالَى وَبَرَكاتُهُ',
#   'السَّوَادُ الأعْظَمُ مِنَ الأمَّةِ لا يَقْرَأُ',
#   'السُّكَّانُ الْمَدَنِيُّونَ» وَالكَلِمَةُ عَكْسُ العَسْكَرِيّ أَيْضا',
#   'السُّوقُ هُوَ مَكَانُ البَيْعِ وَالشِّرَاءِ',
#   'السِّنارْيُو السِّينَمائِيّ أَوِ الْمَسْرَحِيُّ',
#   'الشَّائِعُ أنَّ النَّاسَ فِي تَذَمُّرٍ مُتَزَايِدٍ',
#   'الشَّاةُ الْمَذْبُوحَةُ لاَ يُؤْلِمُهَا السَّلْخُ',
#   'الشَّخْصِيَّاتُ الرَّئِيسَةُ». وَيجُوزُ قَوْل',
#   'الشَّرَفُ لاَ يَنَالُهُ إِلاَّ مَنْ يَخْدُمُ أُمَّتَهُ خِدْمَةً عَظِيمَةً',
#   'الشَّرِيعَةُ قَدْ دُنِّسَتْ بِالجَهَالاَتِ وَاخْتَلَطَتْ بِالضَّلاَلاَتِ',
#   'الشَّرُّ بِالشَّرِّ والبادِئُ أَظْلَمُ',
#   'الشَّعْبُ اليَمَنِيُّ شَعْبُ اليُمْنِ والعَطَاءِ',
#   'الشَّمْسُ تَمُوتُ فِي السَّمَاءِ شَاحِبَةً كَمَا كَانَ وَجْهُ أبِي شَاحِباً وَهُوَ يَموتُ',
#   'الشَّمْسُ مُشْرِقَةٌ فِي كَبِدِ السَّمَاءِ وَهَّاجَةٌ كَعَادَتِهَا فِي مُدُنِ السَّاحِلِ',
#   'الشُّهَداءُ ثَنِيَّةُ اللَّهِ في الأرْضِ',
#   'الشِّدَّةُ لاَ تَدُومُ أَبَداً عَلَى مَخْلُوقٍ',
#   'الشِّرِّيرُ تنُاَزِعُهُ النَّفْسُ إِلَى سُوءِ الظَّنِّ عَلَى الدَّوَامِ',
#   'الصَّبِيُّ مَرِنٌ، نَفْسُهُ كَأَعْضَائِهِ سُرْعَانَ مَا تَتَشَكَّلُ حَسَبَ الوَظِيفَةِ وَحَسَبَ الظُّرُوفِ',
#   'الصَّدَارَةُ فِي اللُّغَةِ وَعِنْدَ النُّحَاةِ',
#   'الصَّدَقَةُ تُطْفِئُ الْخَطِيئَةَ كَمَا يُطْفِئُ الْمَاءُ النَّارَ',
#   'الصَّوْمُ والصَّلاةُ رِياضَةٌ روحِيَّةٌ وَبَدَنِيَّةٌ',
#   'الصِّدْقُ فِي القَوْلِ وَالإِخْلاَصُ فِي العَمَلِ',
#   'الصِّدْقُ مَجْلَبَةٌ لِلسَّلاَمَةِ وَرَاحَةِ الضَّمِيرِ',
#   'الضَّحِكُ بِلاَ سَبَبٍ مِنْ قِلَّةِ الأَدَبِ',
#   'الضَّرُورَاتُ تُبِيحُ الْمَحْظُورَاتِ',
#   'الضَّرْبَةُ الحُرَّةُ غَيْرُ الْمُبَاشِرَةِ',
#   'الطَّبِيبُ يَفْحَصُ وَيُطِيلُ الْفَحْصَ بِأَدَوَاتِهِ',
#   'الطَّهَارَةُ شَرْطٌ مِنْ شُرُوطِ أَدَاءِ الصَّلاَةِ',
#   'الطِّفْلُ إِذا تَشَايَخَ كَالشَّيْخِ إِذَا تَصَابَى',
#   'الظَّرْفُ في النّحْوِ نَوْعانِ: ظَرْفُ مَكانٍ، وَظَرْفُ زَمان',
#   'العَربِيَّةُ أَسْلَسُ حُرُوفاً وَأَرَقُّ لَفْظاً وَأَخَفُّ اسْمًا',
#   'العَيْنُ باصرةٌ واليَدُ قاصرَةٌ',
#   'العَيْنُ بَصيرَةٌ وَاليَدُ قَصيرَةٌ',
#   'العُيُونُ إِلَيْهَا نَاظِرَةٌ وَالقُلُوبُ عَلَيْهَا وَالِهَةٌ',
#   'العِبَادَةُ حِرْفَةٌ وَحَانُوتُهَا الخَلْوَةُ',
#   'العِلْمُ زَيْنٌ لِصَاحِبِهِ فِي الرَّخَاءِ ومَنْجَاةٌ لَهُ فِي الشِّدَّةِ',
#   'العِلْمُ هُوَ الأَصْلُ وَالأَدَبُ هُوَ الفَرْعُ',
#   'العِلْمُ هُوَ الغَايَةُ الشَّرِيفَةُ',
#   'العِلْمُ يَجْلُو العَمَى عَنْ قَلْبِ صَاحِبِهِ',
#   'الغرَام وَحْدَةٌ لِقِيَاسَاتِ الوَزْنِ',
#   'الغَبَنُ فِي البَيْعِ أَوِ الشِّرَاءِ',
#   'الغَلَبَةُ كَمَا هُوَ مَعْرُوفٌ وَمُتَدَاوَلٌ لِلْمُمارِسِ',
#   'الفَصْلُ فِي الأَحْكَامِ مِنْ صَلاَحِيَّةِ القُضَاةِ',
#   'الفِيلُ إِذَا نَامَ اتَّكَأ عَلَى شَجَرَةٍ',
#   'القانونُ الأساسِيُّ في الْمُعَسْكَرِ هُوَ الانْضِباطُ العَسْكَرِيُّ',
#   'القَائِدُ البَانِي، مَدَّنَ الْمُدُنَ وَشَيَّدَ القُصُورَ',
#   'القَضِيَّةُ وَاضِحَةٌ لاَ غُبَارَ عَلَيْهَا',
#   'القَلْبُ مُطْمَئِنٌّ وَالصَّدْرُ مُنْشَرِحٌ',
#   'القَوْلُ فِي اللُّغَاتِ الأُخْرَى غَيْرِ العَرَبِيَّةِ أَشَدُّ تَعَاظُلاً وَتَعَسُّراً',
#   'القُرْآنُ كِتَابٌ نَفِيسٌ مَعَ الدِّينِ الثَّخِينِ وَالعَقْلِ الرَّزِينِ',
#   'الكَاتِبُ عَقْلٌ يُفَكِّرُ وَقَلَمٌ يَكْتُبُ وَيُسَطِّرُ',
#   'الكَسَلُ هُوَ البَاعِثُ الوَحِيدُ عَلَى فَشَلِهِ',
#   'الكَعْبَةُ الْمُشَرَّفَةُ مَطُوفٌ حَوْلَهَا',
#   'الكَلامُ لَفْظٌ مُرَكَّبٌ وَأَقْسامُهُ: اِسْمٌ وَفِعْلٌ وَحَرْفٌ',
#   'الكَلاَمُ سَهْمٌ نَافِذٌ لاَ يُمْكِنُ رَدُّهُ',
#   'الكَلاَمُ يَتَغَيَّرُ الْمُرَادُ فِيهِ بِاخْتِلاَفِ الإِعْرَابِ',
#   'الكَلِمَةُ اِسْمٌ أوْ فِعْلٌ أوْ حَرْفٌ',
#   'الكُلُّ يَتَساءلُ عَنِ سَبَبِ هَذَا التَّقاعُسِ',
#   'الكِتابُ«مُسْنَدُ إِلَيْهِ، وَ»مُفيدٌ» مُسْنَد',
#   'اللَّئيمُ لا يَصِلُ أَحَداً إِلاَّ عِنْدَ رَغْبَةٍ أَوْ رَهْبَةٍ',
#   'اللَّمْسُ يُدْرِكُ الأَمْزِجَةَ وَالصَّلاَبَةَ وَاللِّينَ وَالْخُشُونَةَ',
#   'اللَّهُ إِذَا أَرَادَ ثَمَراً غَرَسَ لَهُ غِرْساً',
#   'اللَّهُ بَديعُ السَّمَواتِ والأرْضِ',
#   'اللَّهُ تَبَارَكَ وَتَعَالَى جَلَّ شَأْنُهُ',
#   'اللَّهُ هُوَ الكَفِيلُ بِرَدِّ كَيْدِ الكَائِدِ',
#   'اللَّهُ وَحْدَهُ هُوَ الَّذِي سَيَتَولَّى مُكَافَأتَهُمْ عَلَى أعْمَالِهِمْ',
#   'اللَّهُ يَعْلَمُ مَا فِي ذَاتِ الصُّدُورِ',
#   'اللَّهُمَّ آوِنِي إلَى ظِلِّ كَرَمِكَ وَعَفْوِكَ',
#   'اللَّهُمَّ إِنَّكَ تَعْلَمُ مَا عَنْ قَصْدٍ أَجْرَمَتْ',
#   'اللَّهُمَّ إِنِّي أَدْرَأُ بِكَ فِي نُحُورِهِمْ',
#   'اللَّهُمَّ اجْعَلْنَا شَاكِرِينَ لِنعْمَتِكَ وَتُبْ عَلَيْنَا إنَّكَ أنْتَ التَّوَّابُ الرَّحِيمُ',
#   'اللَّهُمَّ اجْعَلْنِي مِنَ الأتْقِياءِ',
#   'اللَّهُمَّ اغْفِرْ ذُنُوبِي» الْمُعْتَرِفُ بِالذَّنْبِ كَمَنْ لاَ ذَنْبَ لَه',
#   'اللَّهُمَّ بَارِكْ عَلَى الأنْبِياءِ',
#   'اللَّهُمَّ بَارِكْ عَلَى سَيِّدِنَا مُحَمَّدِ وَعَلَى آلِهِ وَصَحْبِهِ',
#   'اللَّهُمَّ قَوِّنِي وَاحْفَظْنِي فِي هَذِهِ الخَلْوَةِ',
#   'اللَّوْنُ الأَزْرَقُ هُوَ السَّائِدُ فِي اللَّوْحَةِ',
#   'اللَّيْلَةُ رَاحَةٌ لِمَا قَبْلَهَا مِنَ التَّعَبِ وَجِمَامٌ لمِاَ بَعْدَهَا مِنَ العَمَلِ',
#   'اللُّغَةُ الآرَامِيَّةُ لُغَةٌ مَيِّتَةٌ، وَالعَرَبِيَّةُ لُغَةٌ حَيَّةٌ». ',
#   'اللُّغَةُ العَرَبِيَّةُ هِيَ لُغَةُ الضَّادِ',
#   'اللُّغَةُ الفُصْحَى الآن لاَ تَتَغَذَّى كَثِيرًا مِنِ اسْتِعْمَالِ الكَلِمَاتِ اليَوْمِيَّةِ',
#   'المَحَلُّ التِّجَارِيُّ كَائِنٌ فِي آخِرِ الشَّارِعِ',
#   'المِتْرُ وَحْدَةٌ لِقِيَاسَاتِ الطُّولِ«',
#   'المِهْرَجَانُ الدَّوْلِيُّ لِلسِّينِمَا',
#   'النَّاسُ سَواسِيَةٌ كَأَسْنانِ الْمُشْطِ',
#   'النَّاسُ سَواسِيَةٌ لاَ أفْضَلِيَّةَ بَيْنَهُمْ',
#   'النَّاسُ عَلَى طَبَقَاتٍ شَتّى وَالنَّاسُ طَبَقَاتٌ',
#   'النَّاسُ يَكْسِبُونَ عَلَى رَأْسِ كُلِّ سَنَةٍ عَادَةً جَدِيدَةً وَخَلِيقَةً غَيْرَ مَعْهُودَةٍ',
#   'النَّافِيةِ فَتُقْلَبُ لاَماً. إِلاَّ تَنْصُروهُ فَقَدْ نَصَرَهُ اللَّهُ',
#   'النَّاقَةُ، القافِلَةُ تَسِيرُ وَالكِلاَبُ تَنْبَحُ',
#   'النَّبِيُّ مَبْعُوثٌ وَالفَيْلَسُوفُ مَبْعُوثٌ إِلَيْهِ',
#   'النَّجْمُ الْقُطْبِيُّ«، يُهْتَدَى بِهِ، وَبِجَانِبِهِ نَجْمٌ آخَرُ أَخْفَى وَأَصْغَرُ مِنْهُ، وهُمَا الْفَرْقَدَان',
#   'النَّحَافَةُ أنَاقَةُ العَصْرِ عِنْدَ الْمَرْأَةِ',
#   'النَّخْلَةُ جِذْعُهَا نَمَّاءٌ وَلِيفُهَا رَشَّاءٌ',
#   'النَّسْرُ يَنامُ في شَظايا الجَبَلِ وَثَناياهُ',
#   'النَّميمَةُ دَناءةٌ والسِّعايَةُ رَداءةٌ',
#   'النَّوْمُ الثَّقِيلُ مَجْلَبَةٌ لِلْمَرَضِ',
#   'النُّجُومُ وَبُرُوجُهَا وَحِسَابُهَا الَّذِي يُعْرَفُ بِهِ الأَوْقَاتُ وَالأَزْمِنَةُ',
#   'النُّقْطَةُ الدَّائِمَةُ تَثْقُبُ الْحَجَرَ',
#   'النِّطَاقاتُ الذَّهَبِيَّةُ الْمُلْتَفَّةُ على خَصْرٍ أَهيَفَ لا يَضيقُ بِها وإنْ عَرُضَتْ',
#   'الوَحْدَةُ العَرَبِيَّةُ آتِيَةٌ لاَ رَيْبَ فِيهَا',
#   'الوَهْمُ رُوحٌ خَبِيثٌ يُلاَبِسُ الرُّوحَ الإِنْسَانِيَّةَ',
#   'اليَدُ عُضْوٌ مِنْ أَعْضَاءِ الْجِسْمِ',
#   'الِاسْتِسْلامُ أَوِ الْيَأْسُ كِلاَهُمَا يَعْنِي الْفَنَاءَ وَنَحْنُ لاَ نُرِيدُ أَنْ نَفْنَى',
#   'الَّذِي يَعْمَلُ خَيْراً فَلَهُ جَزَاءٌ',
#   'الْبُنْدُقِ«في تُونُسَ، وَ»الدَّرَّاق» في لُبْنَان',
#   'الْجُمْهورِيَّةُ العِراقِيَّةُ» عَاصِمَتُهَا بَغْدَاد. يَقَعُ العِراقُ فِي غَرْبِ آسِيَا بَيْنَ سُورِيَةَ وَالسُّعُودِيَّةِ وَالْكُوَيتِ وَإيرانَ وَتُرْكِيَا وَالأُرْدُن',
#   'الْجِهَاتُ الأَرْبَعُ هِيَ: الشَّرْقُ وَالغَرْبُ واَلشَّمَالُ وَالْجَنُوبُ',
#   'الْحَبَّةُ الْمَدْفُونَةُ فِي الأَرْضِ تَطْلُعُ فَوْقَ الأَرْضِ بِمَعُونَةِ الْمَاءِ الَّذِي يُذْهِبُ عَنْهَا أَذَى اليُبْسِ وَالْمَوْتِ',
#   'الْحَجُّ الْمَبْرُورُ لَيْسَ لَهُ جَزَاءٌ إِلاَّ الجَنَّةُ',
#   'الْحَقُّ مَعَكَ». ب. مَعْنَى زَمَان الاجْتِمَاع',
#   'الْحَقُّ مُعْتَرَفٌ بِهِ وَإِنْ شَغَبَ شاغِبٌ',
#   'الْحَقُّ يَعْلُو وَلاَ يُعْلَى عَلَيْهِ',
#   'الْحَمْدُ للهِ مُمْسَانَا وَمُصْبَحُنَا',
#   'الْحَوَاسِيبُ الإِلِكْتُرُونِيَّةُ مُعْجِزَةٌ مِنْ مُعْجِزَاتِ القرن العشرين',
#   'الْحَيَاةُ أَوِ الْمَوْتُ بِيَدِ اللَّهِ',
#   'الْحَيَّةُ الْمَدْفُونَةُ فِي الأَرْضِ لاَ تَقْدِرُ عَلَى أَنْ تَخْلَعَ سَلْخَها',
#   'الْحُرُوفُ الشَّمْسِيَّةُ هِيَ: ت، ث، د، ذ، ر، ز، س، ش، ص، ض، ط، ظ، ل، ن، أَيِ الْحُرُوفُ الَّتِي لاَ تُلْفَظُ قَبْلَهَ',
#   'الْحُزْنُ وَالْغَمُّ وَالْهَمُّ وَالأَسَى وَالْجُوعُ وَالخَوْفُ مِنْ شَجَرَةٍ وَاحِدَةٍ',
#   'الْعَجَبُ هُوَ النَّظَرُ فِي النَّفْسِ بِعَيْنٍ تَرَى الْقَبِيحَ جَمِيلاً',
#   'الْعَنَاصِرُ الأَرْبَعَةُ عِنْدَ الْقُدَمَاءِ هِيَ: النَّارُ وَالْهَوَاءُ وَالْمَاءُ وَالتُّرَاب',
#   'الْعَيْبُ فِي الرَّجُلِ الْمَذْكُورِ مَذْكُورٌ» هَلْ أَتَى عَلَى الإِنْسَانِ حِينٌ مِنَ الدَّهْرِ لَمْ يَكُنْ شَيْئاً مَذْكُورا',
#   'الْعَيْنُ بَصِيرَةٌ وَالْيَدُ قَصِيرَةٌ',
#   'الْعُقَلاَءُ يَسْتَعْمِلُونَ الْحِكْمَةَ فِي تَوْجِيهِ الأَفْكَارِ نَحْوَ تَأْسِيسِ الْعَدَالَةِ',
#   'الْفَجْرُ لاَ يَطْلُعُ مِنْ لَيْلَةٍ إِلاَّ بَعْدَ أَنْ يَكْتَمِلَ لَيْلُهُ',
#   'الْقسْطلِ@«، و«الْكَسْتُنَاءِ» في مِصْرَ أَيْضاً، وَ بِ',
#   'الْقَاسِمُ الْمُشْتَرَكُ بَيْنَهُمَا هُوَ حُبُّ الْوَطَنِ',
#   'الْقَانِعُ غَنِيٌّ وَإِنْ جَاعَ وَعَرِيَ',
#   'الْقَصَبُ لاَ يَنْبُتُ إِلاَّ عَلَى شُطُوطِ الْأَنْهَارِ',
#   'الْقَضِيَّةُ الْفِلِسْطِينِيَّةُ قَضِيَّةٌ وَطَنِيَّةٌ وعَرَبِيَّةٌ وإِنْسَانِيَّةٌ',
#   'الْقَوْلُ فِي اللُّغَات الأُخْرَى غَيْرِ الْعَرَبِيَّةِ أَشَدُّ تَدَاخُلاً وَتَرَادُفاً',
#   'الْمَالُ السَّائِبُ يُعَلِّمُ النَّاسَ الحَرَامَ',
#   'الْمَبْدَأُ الأَسَاسِيُّ فِي العَمَلِ هُوَ النِّيَّةُ',
#   'الْمَبْعَثُ عَلَى ذَلِكَ هُوَ. . . ',
#   'الْمَثَلُ كَمَا تَرَى بَارِعٌ رَائِعٌ قَاصِمٌ',
#   'الْمَجَازُ الْمُرْسَلُ@«، الْمَجَازُ بِالاسْتِعَارَةِ«',
#   'الْمَجْدُ هُوَ إِحْرَازُ الْمَرْءِ مَقَامَ حُبٍّ وَاحْتِرَامٍ',
#   'الْمَحْسُوبِيَّةُ مِنْ عَنَاصِرِ الفَسَادِ تَجْعَلُ الْحَسَبَ وَالنَّسَبَ فِي الْمَقَامِ الأَوَّلِ وَنَيْلَ الْحُظْوَةِ وَالتَّرْقِيَةِ بَدَلاً مِنَ العَمَلِ',
#   'الْمَدِينَةُ الْحَدِيثَةُ قِوَامُهَا الصَّنَائِعُ وَالفُنُونُ',
#   'الْمَدْيُونِيَّةُ الْخَارِجِيَّةُ تُرْهِقُ كَاهِلَ شُعُوبِ العَالَمِ الثَّالِثِ',
#   'الْمَطْلُوبُ نُسْخَةٌ مِنَ الشَّهَادَةِ طِبْقَ الأَصْلِ',
#   'الْمَعِدَةُ بَيْتُ الدَّاءِ وَالحِمْيَةُ رَأْسُ كُلِّ دَواءٍ',
#   'الْمَغْرِبُ بَلَدٌ مِنْ بُلْدانِ العالَمِ العَرَبِيِّ والإِسْلامِيِّ',
#   'الْمَفْعُولُ لَهُ، الْمَفْعُولُ لأَجْلِهِ',
#   'الْمَكَرُونَةِ» يَكُونُ قِطَعاً صِغَاراً عَلَى هَيْئَةِ أَلْسِنَة',
#   'الْمَنَاطِقُ الَّتي تَقَعُ شَرْقَ البَحْرِ الأَبْيَضِ الْمُتَوَسِّطِ وَشَرْقَ أُورُوبَّا، وَهِيَ أَقْسَامٌ',
#   'الْمَنْزِلُ، فِناءٌ فَسيحٌ في الْمَنْزِلِ الكَبيرِ لِلأُسْرَة',
#   'الْمَوْقِفُ مَوْقِفُ عَمَلٍ لاَ مَوْقِفُ كَلاَمٍ',
#   'الْمُؤْمِنُ أخُو الْمُؤْمِنِ لاَ يَخْذُلُهُ',
#   'الْمُؤْمِنُ بِشَيْءٍ خَيْرٌ مِمَّنْ لاَ يُؤْمِنُ بِشَيءٍ وَلاَ يَرْجُو مَعَاداً',
#   'الْمُبْتَدَأُ فِي النَّحْوِ هُوَ الاسْمُ الَّذِي يَكُونُ بِهِ ابْتِدَاءُ الكَلاَمِ نَحْوُ',
#   'الْمُتَبَادِلُونَ ذَاتَ اليَدِ هُمُ المتَعَاوِنُونَ',
#   ...]}
